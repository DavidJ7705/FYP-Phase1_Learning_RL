# %% [markdown]
# # PPO CartPole

# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"
monitor_file = str(monitor_dir) #/ "monitor_log.csv"

# %% [markdown]
# ## Training Model

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = Monitor(env, monitor_file)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 21.7     |
# | time/              |          |
# |    fps             | 6631     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 4307        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008992369 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000131   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.25        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 51.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.7        |
# |    ep_rew_mean          | 32.7        |
# | time/                   |             |
# |    fps                  | 3927        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010656046 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0933      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 32.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.1        |
# |    ep_rew_mean          | 45.1        |
# | time/                   |             |
# |    fps                  | 3792        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007398878 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 50          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.9        |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 3699        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007562115 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 62.3        |
# -----------------------------------------

# %%
# Reset environment
SEED = 23
observation, info = env.reset(seed=SEED)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:10240
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.01939331  0.01414582 -0.03713558 -0.0386292 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 0
# cart position: 0.019676225259900093
# cart velocity: -0.18042446672916412
# pole angle: -0.0379081629216671
# pole angular velocity: 0.24210967123508453
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 1
# cart position: 0.016067735850811005
# cart velocity: 0.015217890031635761
# pole angle: -0.03306596726179123
# pole angular velocity: -0.06228536367416382
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 0
# cart position: 0.016372092068195343
# cart velocity: -0.1794147491455078
# pole angle: -0.034311674535274506
# pole angular velocity: 0.21978439390659332
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 1
# cart position: 0.012783797457814217
# cart velocity: 0.016180433332920074
# pole angle: -0.029915988445281982
# pole angular velocity: -0.08352135866880417
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 0
# cart position: 0.01310740690678358
# cart velocity: -0.1785001903772354
# pole angle: -0.0315864160656929
# pole angular velocity: 0.19957493245601654
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 1
# cart position: 0.009537402540445328
# cart velocity: 0.017058953642845154
# pole angle: -0.0275949165225029
# pole angular velocity: -0.10290233045816422
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 0
# cart position: 0.009878581389784813
# cart velocity: -0.177656888961792
# pole angle: -0.02965296246111393
# pole angular velocity: 0.18094836175441742
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 1
# cart position: 0.006325444206595421
# cart velocity: 0.017876559868454933
# pole angle: -0.026033995673060417
# pole angular velocity: -0.12093956768512726
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 0
# cart position: 0.006682975217700005
# cart velocity: -0.1768629103899002
# pole angle: -0.028452787548303604
# pole angular velocity: 0.1634175181388855
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 1
# cart position: 0.0031457170844078064
# cart velocity: 0.018654555082321167
# pole angle: -0.02518443576991558
# pole angular velocity: -0.13810396194458008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 0
# cart position: 0.0035188081674277782
# cart velocity: -0.1760977953672409
# pole angle: -0.027946515008807182
# pole angular velocity: 0.14652849733829498
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 1
# cart position: -3.1479237350140465e-06
# cart velocity: 0.01941298134624958
# pole angle: -0.025015946477651596
# pole angular velocity: -0.15483836829662323
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 0
# cart position: 0.0003851116925943643
# cart velocity: -0.17534202337265015
# pole angle: -0.028112713247537613
# pole angular velocity: 0.12984880805015564
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 1
# cart position: -0.003121728776022792
# cart velocity: 0.02017112821340561
# pole angle: -0.025515737012028694
# pole angular velocity: -0.1715690791606903
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 0
# cart position: -0.0027183061465620995
# cart velocity: -0.1745765060186386
# pole angle: -0.028947118669748306
# pole angular velocity: 0.1129564642906189
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 1
# cart position: -0.006209836341440678
# cart velocity: 0.020948011428117752
# pole angle: -0.0266879890114069
# pole angular velocity: -0.18871670961380005
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 0
# cart position: -0.0057908762246370316
# cart velocity: -0.17378215491771698
# pole angle: -0.030462322756648064
# pole angular velocity: 0.0954291969537735
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 1
# cart position: -0.009266518987715244
# cart velocity: 0.021762853488326073
# pole angle: -0.028553739190101624
# pole angular velocity: -0.20670677721500397
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 0
# cart position: -0.008831262588500977
# cart velocity: -0.17293938994407654
# pole angle: -0.032687876373529434
# pole angular velocity: 0.07683388888835907
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: -0.012290050275623798
# cart velocity: -0.36757785081863403
# pole angle: -0.031151197850704193
# pole angular velocity: 0.35902711749076843
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: -0.019641607999801636
# cart velocity: -0.17202724516391754
# pole angle: -0.023970656096935272
# pole angular velocity: 0.056686513125896454
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: -0.023082152009010315
# cart velocity: -0.36679744720458984
# pole angle: -0.022836925461888313
# pole angular velocity: 0.3417111933231354
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: -0.03041810169816017
# cart velocity: -0.1713581532239914
# pole angle: -0.016002701595425606
# pole angular velocity: 0.04191520810127258
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: -0.033845264464616776
# cart velocity: -0.3662469983100891
# pole angle: -0.015164397656917572
# pole angular velocity: 0.3295064866542816
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: -0.04117020592093468
# cart velocity: -0.170912504196167
# pole angle: -0.008574267849326134
# pole angular velocity: 0.03208024799823761
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: -0.04458845406770706
# cart velocity: -0.36591047048568726
# pole angle: -0.007932662963867188
# pole angular velocity: 0.32204562425613403
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 1
# cart position: -0.05190666392445564
# cart velocity: -0.17067644000053406
# pole angle: -0.0014917502412572503
# pole angular velocity: 0.026871638372540474
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 0
# cart position: -0.055320192128419876
# cart velocity: -0.36577698588371277
# pole angle: -0.0009543175110593438
# pole angular velocity: 0.3190835416316986
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 1
# cart position: -0.06263573467731476
# cart velocity: -0.1706414371728897
# pole angle: 0.005427353084087372
# pole angular velocity: 0.0260997973382473
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 0
# cart position: -0.06604856252670288
# cart velocity: -0.3658407926559448
# pole angle: 0.005949349142611027
# pole angular velocity: 0.32049015164375305
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 1
# cart position: -0.07336537539958954
# cart velocity: -0.17080408334732056
# pole angle: 0.012359152548015118
# pole angular velocity: 0.029689352959394455
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 0
# cart position: -0.07678145915269852
# cart velocity: -0.36610105633735657
# pole angle: 0.012952939607203007
# pole angular velocity: 0.3262459635734558
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 1
# cart position: -0.08410347998142242
# cart velocity: -0.17116591334342957
# pole angle: 0.019477859139442444
# pole angular velocity: 0.03767580911517143
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 1
# cart position: -0.08752679824829102
# cart velocity: 0.023671388626098633
# pole angle: 0.020231375470757484
# pole angular velocity: -0.24879857897758484
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: -0.08705337345600128
# cart velocity: -0.171733558177948
# pole angle: 0.015255402773618698
# pole angular velocity: 0.05019648000597954
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: -0.09048803895711899
# cart velocity: 0.023166362196207047
# pole angle: 0.01625933311879635
# pole angular velocity: -0.23763446509838104
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: -0.09002471715211868
# cart velocity: -0.1721840500831604
# pole angle: 0.011506643146276474
# pole angular velocity: 0.0601324625313282
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 1
# cart position: -0.09346839785575867
# cart velocity: 0.022771038115024567
# pole angle: 0.012709292583167553
# pole angular velocity: -0.22889794409275055
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 0
# cart position: -0.0930129736661911
# cart velocity: -0.17253020405769348
# pole angle: 0.008131333626806736
# pole angular velocity: 0.0677666962146759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 1
# cart position: -0.09646357595920563
# cart velocity: 0.022474229335784912
# pole angle: 0.009486667811870575
# pole angular velocity: -0.2223397046327591
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 0
# cart position: -0.0960140973329544
# cart velocity: -0.1727820187807083
# pole angle: 0.005039873532950878
# pole angular velocity: 0.07332053780555725
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 1
# cart position: -0.09946973621845245
# cart velocity: 0.022267313674092293
# pole angle: 0.006506284233182669
# pole angular velocity: -0.21776804327964783
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 0
# cart position: -0.09902438521385193
# cart velocity: -0.17294703423976898
# pole angle: 0.002150923479348421
# pole angular velocity: 0.07696012407541275
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 1
# cart position: -0.10248333215713501
# cart velocity: 0.02214401215314865
# pole angle: 0.003690126119181514
# pole angular velocity: -0.21504339575767517
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 0
# cart position: -0.10204044729471207
# cart velocity: -0.17303049564361572
# pole angle: -0.0006107420194894075
# pole angular velocity: 0.07880126684904099
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 1
# cart position: -0.10550105571746826
# cart velocity: 0.02210020087659359
# pole angle: 0.0009652833687141538
# pole angular velocity: -0.2140742838382721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 0
# cart position: -0.10505905747413635
# cart velocity: -0.17303553223609924
# pole angle: -0.0033162024337798357
# pole angular velocity: 0.07891298085451126
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 1
# cart position: -0.10851976275444031
# cart velocity: 0.02213379554450512
# pole angle: -0.0017379428027197719
# pole angular velocity: -0.21481437981128693
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 0
# cart position: -0.10807708650827408
# cart velocity: -0.17296326160430908
# pole angle: -0.006034230347722769
# pole angular velocity: 0.07731982320547104
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 1
# cart position: -0.11153635382652283
# cart velocity: 0.022244667634367943
# pole angle: -0.0044878339394927025
# pole angular velocity: -0.21726080775260925
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 0
# cart position: -0.11109146475791931
# cart velocity: -0.17281284928321838
# pole angle: -0.008833049796521664
# pole angular velocity: 0.07400310039520264
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 1
# cart position: -0.1145477220416069
# cart velocity: 0.022434620186686516
# pole angle: -0.0073529877699911594
# pole angular velocity: -0.22145354747772217
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 0
# cart position: -0.11409902572631836
# cart velocity: -0.17258146405220032
# pole angle: -0.011782058514654636
# pole angular velocity: 0.06890090554952621
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 1
# cart position: -0.11755065619945526
# cart velocity: 0.02270740643143654
# pole angle: -0.010404041036963463
# pole angular velocity: -0.22747591137886047
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 0
# cart position: -0.11709650605916977
# cart velocity: -0.17226432263851166
# pole angle: -0.014953559264540672
# pole angular velocity: 0.06190712749958038
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 1
# cart position: -0.12054179608821869
# cart velocity: 0.02306879684329033
# pole angle: -0.013715416193008423
# pole angular velocity: -0.23545598983764648
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 0
# cart position: -0.12008041888475418
# cart velocity: -0.17185454070568085
# pole angle: -0.018424537032842636
# pole angular velocity: 0.052869316190481186
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 1
# cart position: -0.12351750582456589
# cart velocity: 0.023526683449745178
# pole angle: -0.017367150634527206
# pole angular velocity: -0.24556928873062134
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 0
# cart position: -0.12304697185754776
# cart velocity: -0.17134296894073486
# pole angle: -0.02227853611111641
# pole angular velocity: 0.04158542677760124
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 0
# cart position: -0.1264738291501999
# cart velocity: -0.3661384880542755
# pole angle: -0.021446827799081802
# pole angular velocity: 0.32715684175491333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 1
# cart position: -0.1337966024875641
# cart velocity: -0.17071786522865295
# pole angle: -0.014903690665960312
# pole angular velocity: 0.027788439765572548
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 0
# cart position: -0.13721096515655518
# cart velocity: -0.36562293767929077
# pole angle: -0.014347921125590801
# pole angular velocity: 0.31573209166526794
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 1
# cart position: -0.14452342689037323
# cart velocity: -0.17029958963394165
# pole angle: -0.00803328026086092
# pole angular velocity: 0.018559055402874947
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 0
# cart position: -0.14792941510677338
# cart velocity: -0.36530542373657227
# pole angle: -0.007662098854780197
# pole angular velocity: 0.30869659781455994
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 1
# cart position: -0.15523551404476166
# cart velocity: -0.17007513344287872
# pole angle: -0.0014881667448207736
# pole angular velocity: 0.013607140630483627
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 0
# cart position: -0.15863701701164246
# cart velocity: -0.365175724029541
# pole angle: -0.0012160239275544882
# pole angular velocity: 0.30582016706466675
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 1
# cart position: -0.1659405380487442
# cart velocity: -0.1700364649295807
# pole angle: 0.004900379106402397
# pole angular velocity: 0.012753979302942753
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 0
# cart position: -0.16934126615524292
# cart velocity: -0.3652283549308777
# pole angle: 0.005155459046363831
# pole angular velocity: 0.3069790005683899
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 1
# cart position: -0.17664583027362823
# cart velocity: -0.17018023133277893
# pole angle: 0.01129503920674324
# pole angular velocity: 0.015926418825984
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 1
# cart position: -0.18004943430423737
# cart velocity: 0.02477792650461197
# pole angle: 0.011613567359745502
# pole angular velocity: -0.27317148447036743
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 0
# cart position: -0.17955388128757477
# cart velocity: -0.1705077886581421
# pole angle: 0.0061501371674239635
# pole angular velocity: 0.023151637986302376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 1
# cart position: -0.1829640418291092
# cart velocity: 0.024525422602891922
# pole angle: 0.006613169796764851
# pole angular velocity: -0.26758453249931335
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 0
# cart position: -0.18247352540493011
# cart velocity: -0.17069028317928314
# pole angle: 0.001261479570530355
# pole angular velocity: 0.027176888659596443
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 1
# cart position: -0.18588733673095703
# cart velocity: 0.02441355586051941
# pole angle: 0.0018050173530355096
# pole angular velocity: -0.26510775089263916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 0
# cart position: -0.18539905548095703
# cart velocity: -0.17073410749435425
# pole angle: -0.0034971379209309816
# pole angular velocity: 0.02814393863081932
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 1
# cart position: -0.18881374597549438
# cart velocity: 0.024437816813588142
# pole angle: -0.0029342591296881437
# pole angular velocity: -0.2656403183937073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 0
# cart position: -0.18832498788833618
# cart velocity: -0.17064213752746582
# pole angle: -0.008247065357863903
# pole angular velocity: 0.026115674525499344
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 1
# cart position: -0.1917378306388855
# cart velocity: 0.024597112089395523
# pole angle: -0.0077247521840035915
# pole angular velocity: -0.2691578269004822
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 0
# cart position: -0.1912458837032318
# cart velocity: -0.17041374742984772
# pole angle: -0.013107908889651299
# pole angular velocity: 0.021078675985336304
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: -0.1946541666984558
# cart velocity: -0.365345299243927
# pole angle: -0.012686335481703281
# pole angular velocity: 0.3095972537994385
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: -0.20196107029914856
# cart velocity: -0.1700449138879776
# pole angle: -0.006494390312582254
# pole angular velocity: 0.012940565124154091
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 0
# cart position: -0.2053619623184204
# cart velocity: -0.3650731146335602
# pole angle: -0.006235579028725624
# pole angular velocity: 0.30356737971305847
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 1
# cart position: -0.2126634269952774
# cart velocity: -0.16986286640167236
# pole angle: -0.0001642313291085884
# pole angular velocity: 0.008924433961510658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 0
# cart position: -0.21606068313121796
# cart velocity: -0.3649824559688568
# pole angle: 1.4257343536883127e-05
# pole angular velocity: 0.3015555441379547
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 1
# cart position: -0.2233603298664093
# cart velocity: -0.16986070573329926
# pole angle: 0.006045368034392595
# pole angular velocity: 0.008877108804881573
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 1
# cart position: -0.22675755620002747
# cart velocity: 0.02517402172088623
# pole angle: 0.00622291024774313
# pole angular velocity: -0.281892329454422
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 0
# cart position: -0.22625407576560974
# cart velocity: -0.17003613710403442
# pole angle: 0.000585063942708075
# pole angular velocity: 0.012746775522828102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 1
# cart position: -0.22965478897094727
# cart velocity: 0.025077419355511665
# pole angle: 0.0008399994694627821
# pole angular velocity: -0.2797515094280243
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 0
# cart position: -0.22915324568748474
# cart velocity: -0.1700565069913864
# pole angle: -0.004755030386149883
# pole angular velocity: 0.013196242973208427
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: -0.2325543761253357
# cart velocity: 0.025133315473794937
# pole angle: -0.004491105675697327
# pole angular velocity: -0.2809831500053406
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: -0.23205171525478363
# cart velocity: -0.1699242889881134
# pole angle: -0.010110768489539623
# pole angular velocity: 0.010279919020831585
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 0
# cart position: -0.23545019328594208
# cart velocity: -0.36489978432655334
# pole angle: -0.009905170649290085
# pole angular velocity: 0.29975569248199463
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 1
# cart position: -0.2427481859922409
# cart velocity: -0.16963805258274078
# pole angle: -0.0039100563153624535
# pole angular velocity: 0.003965410869568586
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 0
# cart position: -0.2461409568786621
# cart velocity: -0.3647037148475647
# pole angle: -0.003830747911706567
# pole angular velocity: 0.2954120934009552
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 1
# cart position: -0.25343501567840576
# cart velocity: -0.16952736675739288
# pole angle: 0.0020774940494447947
# pole angular velocity: 0.0015234880847856402
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 1
# cart position: -0.2568255662918091
# cart velocity: 0.025564732030034065
# pole angle: 0.0021079638972878456
# pole angular velocity: -0.29050323367118835
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 0
# cart position: -0.2563142776489258
# cart velocity: -0.16958720982074738
# pole angle: -0.003702100832015276
# pole angular velocity: 0.0028437678702175617
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 1
# cart position: -0.2597060203552246
# cart velocity: 0.02558763511478901
# pole angle: -0.0036452256608754396
# pole angular velocity: -0.2910049259662628
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 0
# cart position: -0.2591942548751831
# cart velocity: -0.16948215663433075
# pole angle: -0.009465323761105537
# pole angular velocity: 0.0005261262995190918
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 0
# cart position: -0.2625839114189148
# cart velocity: -0.3644670844078064
# pole angle: -0.009454801678657532
# pole angular velocity: 0.2902076542377472
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 1
# cart position: -0.2698732614517212
# cart velocity: -0.16921159625053406
# pole angle: -0.0036506480537354946
# pole angular velocity: -0.0054421438835561275
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 0
# cart position: -0.2732574939727783
# cart velocity: -0.3642809987068176
# pole angle: -0.0037594910245388746
# pole angular velocity: 0.2860867381095886
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 1
# cart position: -0.28054311871528625
# cart velocity: -0.1691056340932846
# pole angle: 0.00196224357932806
# pole angular velocity: -0.007779539562761784
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 0
# cart position: -0.28392520546913147
# cart velocity: -0.3642556667327881
# pole angle: 0.0018066527554765344
# pole angular velocity: 0.28552186489105225
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 1
# cart position: -0.2912103235721588
# cart velocity: -0.16915954649448395
# pole angle: 0.007517090067267418
# pole angular velocity: -0.006590722128748894
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 1
# cart position: -0.2945935130119324
# cart velocity: 0.025853803381323814
# pole angle: 0.007385275326669216
# pole angular velocity: -0.2968924641609192
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 0
# cart position: -0.29407644271850586
# cart velocity: -0.16937264800071716
# pole angle: 0.0014474260387942195
# pole angular velocity: -0.001889530336484313
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 1
# cart position: -0.29746389389038086
# cart velocity: 0.025728518143296242
# pole angle: 0.0014096354134380817
# pole angular velocity: -0.29411542415618896
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 0
# cart position: -0.2969493269920349
# cart velocity: -0.1694135069847107
# pole angle: -0.004472672939300537
# pole angular velocity: -0.0009882532758638263
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 1
# cart position: -0.30033761262893677
# cart velocity: 0.025772307068109512
# pole angle: -0.004492437932640314
# pole angular velocity: -0.29507899284362793
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 0
# cart position: -0.2998221516609192
# cart velocity: -0.16928531229496002
# pole angle: -0.010394018143415451
# pole angular velocity: -0.003816298907622695
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 0
# cart position: -0.3032078742980957
# cart velocity: -0.36425668001174927
# pole angle: -0.010470343753695488
# pole angular velocity: 0.2855691611766815
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 1
# cart position: -0.31049299240112305
# cart velocity: -0.1689869612455368
# pole angle: -0.004758961033076048
# pole angular velocity: -0.010397571139037609
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 0
# cart position: -0.31387272477149963
# cart velocity: -0.364040344953537
# pole angle: -0.00496691232547164
# pole angular velocity: 0.28078004717826843
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 1
# cart position: -0.32115355134010315
# cart velocity: -0.16884788870811462
# pole angle: 0.0006486885831691325
# pole angular velocity: -0.013465272262692451
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 1
# cart position: -0.3245305120944977
# cart velocity: 0.026264745742082596
# pole angle: 0.0003793831274379045
# pole angular velocity: -0.30594345927238464
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: -0.32400521636009216
# cart velocity: -0.16886261105537415
# pole angle: -0.0057394858449697495
# pole angular velocity: -0.013140908442437649
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 0
# cart position: -0.3273824453353882
# cart velocity: -0.3639017939567566
# pole angle: -0.006002304144203663
# pole angular velocity: 0.2777256369590759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 1
# cart position: -0.33466050028800964
# cart velocity: -0.16869471967220306
# pole angle: -0.0004477916518226266
# pole angular velocity: -0.016844360157847404
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 1
# cart position: -0.33803439140319824
# cart velocity: 0.026433654129505157
# pole angle: -0.0007846788503229618
# pole angular velocity: -0.30966854095458984
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 0
# cart position: -0.3375056982040405
# cart velocity: -0.16867710649967194
# pole angle: -0.006978049408644438
# pole angular velocity: -0.01723317801952362
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 0
# cart position: -0.34087926149368286
# cart velocity: -0.3636983036994934
# pole angle: -0.007322713267058134
# pole angular velocity: 0.27323994040489197
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 1
# cart position: -0.3481532335281372
# cart velocity: -0.16847263276576996
# pole angle: -0.0018579141469672322
# pole angular velocity: -0.02174355834722519
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 0
# cart position: -0.35152268409729004
# cart velocity: -0.36356788873672485
# pole angle: -0.0022927853278815746
# pole angular velocity: 0.2703526020050049
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 1
# cart position: -0.35879403352737427
# cart velocity: -0.16841329634189606
# pole angle: 0.0031142665538936853
# pole angular velocity: -0.023052603006362915
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 1
# cart position: -0.3621622920036316
# cart velocity: 0.02666386030614376
# pole angle: 0.0026532146148383617
# pole angular velocity: -0.3147513270378113
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 0
# cart position: -0.36162900924682617
# cart velocity: -0.1684957891702652
# pole angle: -0.0036418118979781866
# pole angular velocity: -0.021232837811112404
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 0
# cart position: -0.3649989366531372
# cart velocity: -0.3635653257369995
# pole angle: -0.004066468682140112
# pole angular velocity: 0.2702988386154175
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 1
# cart position: -0.37227022647857666
# cart velocity: -0.1683855801820755
# pole angle: 0.0013395081041380763
# pole angular velocity: -0.023663898929953575
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 1
# cart position: -0.375637948513031
# cart velocity: 0.026717139407992363
# pole angle: 0.0008662301115691662
# pole angular velocity: -0.31592389941215515
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 0
# cart position: -0.375103622674942
# cart velocity: -0.16841714084148407
# pole angle: -0.005452247802168131
# pole angular velocity: -0.02296791411936283
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 0
# cart position: -0.3784719407558441
# cart velocity: -0.3634604811668396
# pole angle: -0.005911605898290873
# pole angular velocity: 0.26798978447914124
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 1
# cart position: -0.3857411742210388
# cart velocity: -0.16825465857982635
# pole angle: -0.0005518102552741766
# pole angular velocity: -0.02655182033777237
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 1
# cart position: -0.38910624384880066
# cart velocity: 0.026875199750065804
# pole angle: -0.001082846662029624
# pole angular velocity: -0.3194088041782379
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 0
# cart position: -0.3885687589645386
# cart velocity: -0.1682313084602356
# pole angle: -0.007471022661775351
# pole angular velocity: -0.027067556977272034
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 0
# cart position: -0.3919333815574646
# cart velocity: -0.3632453382015228
# pole angle: -0.008012373931705952
# pole angular velocity: 0.26324886083602905
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 1
# cart position: -0.3991982936859131
# cart velocity: -0.1680099368095398
# pole angle: -0.002747396705672145
# pole angular velocity: -0.0319504588842392
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 0
# cart position: -0.40255847573280334
# cart velocity: -0.3630923926830292
# pole angle: -0.0033864059951156378
# pole angular velocity: 0.25986436009407043
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 1
# cart position: -0.4098203182220459
# cart velocity: -0.167922243475914
# pole angle: 0.0018108813092112541
# pole angular velocity: -0.03388474881649017
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 1
# cart position: -0.41317877173423767
# cart velocity: 0.027173686772584915
# pole angle: 0.001133186393417418
# pole angular velocity: -0.3259957730770111
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: -0.41263529658317566
# cart velocity: -0.1679643839597702
# pole angle: -0.005386729259043932
# pole angular velocity: -0.032955706119537354
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 0
# cart position: -0.4159945845603943
# cart velocity: -0.36300867795944214
# pole angle: -0.0060458434745669365
# pole angular velocity: 0.2580227851867676
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 1
# cart position: -0.42325475811958313
# cart velocity: -0.1678009331226349
# pole angle: -0.0008853873587213457
# pole angular velocity: -0.03656093031167984
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 1
# cart position: -0.4266107678413391
# cart velocity: 0.027333706617355347
# pole angle: -0.0016166059067472816
# pole angular velocity: -0.32952308654785156
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 0
# cart position: -0.4260641038417816
# cart velocity: -0.16776520013809204
# pole angle: -0.008207067847251892
# pole angular velocity: -0.03735039010643959
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 0
# cart position: -0.4294193983078003
# cart velocity: -0.3627685010433197
# pole angle: -0.008954075165092945
# pole angular velocity: 0.2527318596839905
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 1
# cart position: -0.4366747736930847
# cart velocity: -0.16751983761787415
# pole angle: -0.003899437841027975
# pole angular velocity: -0.04276183620095253
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 0
# cart position: -0.4400251805782318
# cart velocity: -0.3625856637954712
# pole angle: -0.00475467462092638
# pole angular velocity: 0.2486882358789444
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 1
# cart position: -0.44727689027786255
# cart velocity: -0.16739612817764282
# pole angle: 0.00021909002680331469
# pole angular velocity: -0.04549062252044678
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 0
# cart position: -0.45062482357025146
# cart velocity: -0.362521231174469
# pole angle: -0.0006907223723828793
# pole angular velocity: 0.2472614198923111
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 1
# cart position: -0.45787525177001953
# cart velocity: -0.1673894226551056
# pole angle: 0.004254505969583988
# pole angular velocity: -0.045639295130968094
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 1
# cart position: -0.4612230360507965
# cart velocity: 0.027671270072460175
# pole angle: 0.0033417202066630125
# pole angular velocity: -0.3369768559932709
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 0
# cart position: -0.460669606924057
# cart velocity: -0.16749808192253113
# pole angle: -0.0033978167921304703
# pole angular velocity: -0.04324200376868248
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 1
# cart position: -0.4640195667743683
# cart velocity: 0.027672434225678444
# pole angle: -0.004262656904757023
# pole angular velocity: -0.33699503540992737
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 0
# cart position: -0.4634661078453064
# cart velocity: -0.16738860309123993
# pole angle: -0.01100255735218525
# pole angular velocity: -0.04565936326980591
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 0
# cart position: -0.4668138921260834
# cart velocity: -0.36235105991363525
# pole angle: -0.011915745213627815
# pole angular velocity: 0.2435319423675537
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 1
# cart position: -0.47406089305877686
# cart velocity: -0.1670609563589096
# pole angle: -0.007045106031000614
# pole angular velocity: -0.05288555845618248
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 0
# cart position: -0.47740212082862854
# cart velocity: -0.3620811998844147
# pole angle: -0.008102817460894585
# pole angular velocity: 0.237566277384758
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 1
# cart position: -0.48464375734329224
# cart velocity: -0.1668444126844406
# pole angle: -0.003351491643115878
# pole angular velocity: -0.05766146257519722
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 0
# cart position: -0.4879806339740753
# cart velocity: -0.3619181513786316
# pole angle: -0.00450472068041563
# pole angular velocity: 0.23396216332912445
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 1
# cart position: -0.49521899223327637
# cart velocity: -0.16673213243484497
# pole angle: 0.00017452244355808944
# pole angular velocity: -0.0601382851600647
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 0
# cart position: -0.49855363368988037
# cart velocity: -0.3618565797805786
# pole angle: -0.0010282432194799185
# pole angular velocity: 0.23259970545768738
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 163:
# Action taken: 1
# cart position: -0.5057907700538635
# cart velocity: -0.1667199581861496
# pole angle: 0.0036237507592886686
# pole angular velocity: -0.06040739268064499
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 164:
# Action taken: 0
# cart position: -0.5091251730918884
# cart velocity: -0.3618936836719513
# pole angle: 0.00241560279391706
# pole angular velocity: 0.23341664671897888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 165:
# Action taken: 1
# cart position: -0.5163630247116089
# cart velocity: -0.16680632531642914
# pole angle: 0.007083935663104057
# pole angular velocity: -0.058503344655036926
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 166:
# Action taken: 1
# cart position: -0.5196991562843323
# cart velocity: 0.028213344514369965
# pole angle: 0.005913869012147188
# pole angular velocity: -0.3489428460597992
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 167:
# Action taken: 0
# cart position: -0.5191348791122437
# cart velocity: -0.1669922173023224
# pole angle: -0.001064987969584763
# pole angular velocity: -0.054400958120822906
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 168:
# Action taken: 1
# cart position: -0.5224747657775879
# cart velocity: 0.028144989162683487
# pole angle: -0.0021530070807784796
# pole angular velocity: -0.34741970896720886
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 169:
# Action taken: 0
# cart position: -0.5219118595123291
# cart velocity: -0.16694627702236176
# pole angle: -0.009101401083171368
# pole angular velocity: -0.05541647598147392
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 170:
# Action taken: 0
# cart position: -0.5252507925033569
# cart velocity: -0.3619365394115448
# pole angle: -0.010209730826318264
# pole angular velocity: 0.2343810498714447
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 171:
# Action taken: 1
# cart position: -0.532489538192749
# cart velocity: -0.16667021811008453
# pole angle: -0.005522110033780336
# pole angular velocity: -0.0615047849714756
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 172:
# Action taken: 0
# cart position: -0.5358229279518127
# cart velocity: -0.36171257495880127
# pole angle: -0.0067522055469453335
# pole angular velocity: 0.22943077981472015
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 173:
# Action taken: 1
# cart position: -0.5430571436882019
# cart velocity: -0.16649477183818817
# pole angle: -0.002163589932024479
# pole angular velocity: -0.06537435948848724
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 174:
# Action taken: 0
# cart position: -0.5463870763778687
# cart velocity: -0.3615856468677521
# pole angle: -0.003471077186986804
# pole angular velocity: 0.22662515938282013
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 175:
# Action taken: 1
# cart position: -0.5536187887191772
# cart velocity: -0.1664142608642578
# pole angle: 0.0010614258935675025
# pole angular velocity: -0.06715065240859985
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 176:
# Action taken: 1
# cart position: -0.5569470524787903
# cart velocity: 0.0286924596875906
# pole angle: -0.0002815870975609869
# pole angular velocity: -0.3594985008239746
# Reward: 1.0
# Terminated: False, Truncated: False
# ...
# cart position: -1.0851500034332275
# cart velocity: -0.5278667211532593
# pole angle: -0.08256512880325317
# pole angular velocity: -0.11729861050844193
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 276:
# Action taken: 0
# cart position: -1.0957072973251343
# cart velocity: -0.7217145562171936
# pole angle: -0.08491110056638718
# pole angular velocity: 0.14823606610298157
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 277:
# Action taken: 1
# cart position: -1.110141634941101
# cart velocity: -0.5254858136177063
# pole angle: -0.08194638043642044
# pole angular velocity: -0.1699805110692978
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 278:
# Action taken: 0
# cart position: -1.120651364326477
# cart velocity: -0.7193450331687927
# pole angle: -0.08534599095582962
# pole angular velocity: 0.09576726704835892
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 279:
# Action taken: 1
# cart position: -1.1350382566452026
# cart velocity: -0.5231101512908936
# pole angle: -0.08343064785003662
# pole angular velocity: -0.22257499396800995
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 280:
# Action taken: 0
# cart position: -1.1455004215240479
# cart velocity: -0.7169466614723206
# pole angle: -0.0878821462392807
# pole angular velocity: 0.04266826808452606
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 281:
# Action taken: 1
# cart position: -1.159839391708374
# cart velocity: -0.5206815600395203
# pole angle: -0.08702877908945084
# pole angular velocity: -0.2763972878456116
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 282:
# Action taken: 0
# cart position: -1.170253038406372
# cart velocity: -0.714461088180542
# pole angle: -0.09255672991275787
# pole angular velocity: -0.012382308952510357
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 283:
# Action taken: 1
# cart position: -1.184542179107666
# cart velocity: -0.5181419849395752
# pole angle: -0.09280437231063843
# pole angular velocity: -0.33277326822280884
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 284:
# Action taken: 0
# cart position: -1.1949050426483154
# cart velocity: -0.7118289470672607
# pole angle: -0.09945984184741974
# pole angular velocity: -0.07073844224214554
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 285:
# Action taken: 0
# cart position: -1.2091416120529175
# cart velocity: -0.9053947329521179
# pole angle: -0.10087461024522781
# pole angular velocity: 0.1889823079109192
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 286:
# Action taken: 1
# cart position: -1.2272495031356812
# cart velocity: -0.7089851498603821
# pole angle: -0.09709496051073074
# pole angular velocity: -0.13374127447605133
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 287:
# Action taken: 0
# cart position: -1.2414292097091675
# cart velocity: -0.9025918841362
# pole angle: -0.09976978600025177
# pole angular velocity: 0.12679994106292725
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 288:
# Action taken: 1
# cart position: -1.2594810724258423
# cart velocity: -0.706192672252655
# pole angle: -0.09723378717899323
# pole angular velocity: -0.19561751186847687
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 289:
# Action taken: 0
# cart position: -1.2736048698425293
# cart velocity: -0.8997990489006042
# pole angle: -0.1011461392045021
# pole angular velocity: 0.06487858295440674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 290:
# Action taken: 1
# cart position: -1.2916009426116943
# cart velocity: -0.7033833265304565
# pole angle: -0.09984856843948364
# pole angular velocity: -0.25792548060417175
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 291:
# Action taken: 0
# cart position: -1.305668592453003
# cart velocity: -0.8969485759735107
# pole angle: -0.10500707477331161
# pole angular velocity: 0.0016694603255018592
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 292:
# Action taken: 1
# cart position: -1.3236075639724731
# cart velocity: -0.7004896402359009
# pole angle: -0.1049736887216568
# pole angular velocity: -0.3222111165523529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 293:
# Action taken: 0
# cart position: -1.33761727809906
# cart velocity: -0.8939723372459412
# pole angle: -0.11141791194677353
# pole angular velocity: -0.06439029425382614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 294:
# Action taken: 0
# cart position: -1.3554967641830444
# cart velocity: -1.0873351097106934
# pole angle: -0.11270571500062943
# pole angular velocity: 0.19116631150245667
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 295:
# Action taken: 1
# cart position: -1.3772435188293457
# cart velocity: -0.8907963633537292
# pole angle: -0.10888238996267319
# pole angular velocity: -0.13483676314353943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 296:
# Action taken: 0
# cart position: -1.3950594663619995
# cart velocity: -1.084203839302063
# pole angle: -0.11157912760972977
# pole angular velocity: 0.12160836160182953
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 297:
# Action taken: 1
# cart position: -1.416743516921997
# cart velocity: -0.887674868106842
# pole angle: -0.10914696007966995
# pole angular velocity: -0.2040882259607315
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 298:
# Action taken: 0
# cart position: -1.4344969987869263
# cart velocity: -1.081080436706543
# pole angle: -0.11322872340679169
# pole angular velocity: 0.052268218249082565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 299:
# Action taken: 1
# cart position: -1.4561185836791992
# cart velocity: -0.8845323324203491
# pole angle: -0.1121833547949791
# pole angular velocity: -0.2738841474056244
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 300:
# Action taken: 0
# cart position: -1.4738092422485352
# cart velocity: -1.0778898000717163
# pole angle: -0.11766104400157928
# pole angular velocity: -0.018583938479423523
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 301:
# Action taken: 1
# cart position: -1.4953670501708984
# cart velocity: -0.8812941908836365
# pole angle: -0.11803271621465683
# pole angular velocity: -0.34595099091529846
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 302:
# Action taken: 0
# cart position: -1.5129928588867188
# cart velocity: -1.0745567083358765
# pole angle: -0.12495174258947372
# pole angular velocity: -0.09269531816244125
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 303:
# Action taken: 0
# cart position: -1.5344840288162231
# cart velocity: -1.2676868438720703
# pole angle: -0.1268056482076645
# pole angular velocity: 0.15810100734233856
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 304:
# Action taken: 1
# cart position: -1.559837818145752
# cart velocity: -1.070999026298523
# pole angle: -0.12364362925291061
# pole angular velocity: -0.17174294590950012
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 305:
# Action taken: 0
# cart position: -1.5812578201293945
# cart velocity: -1.264154314994812
# pole angle: -0.12707848846912384
# pole angular velocity: 0.07951948791742325
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 306:
# Action taken: 1
# cart position: -1.6065407991409302
# cart velocity: -1.067461371421814
# pole angle: -0.12548810243606567
# pole angular velocity: -0.25040143728256226
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 307:
# Action taken: 0
# cart position: -1.6278901100158691
# cart velocity: -1.2605887651443481
# pole angle: -0.13049612939357758
# pole angular velocity: 0.00021498951537068933
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 308:
# Action taken: 1
# cart position: -1.6531018018722534
# cart velocity: -1.0638601779937744
# pole angle: -0.13049182295799255
# pole angular velocity: -0.33062583208084106
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 309:
# Action taken: 0
# cart position: -1.6743791103363037
# cart velocity: -1.2569066286087036
# pole angle: -0.1371043473482132
# pole angular velocity: -0.08177398145198822
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 310:
# Action taken: 0
# cart position: -1.6995171308517456
# cart velocity: -1.4498239755630493
# pole angle: -0.13873982429504395
# pole angular velocity: 0.1647041141986847
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 311:
# Action taken: 1
# cart position: -1.7285137176513672
# cart velocity: -1.2530168294906616
# pole angle: -0.1354457437992096
# pole angular velocity: -0.16832874715328217
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 312:
# Action taken: 0
# cart position: -1.753574013710022
# cart velocity: -1.4459662437438965
# pole angle: -0.13881231844425201
# pole angular velocity: 0.07874523848295212
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 313:
# Action taken: 1
# cart position: -1.7824933528900146
# cart velocity: -1.2491556406021118
# pole angle: -0.13723741471767426
# pole angular velocity: -0.2543110251426697
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 314:
# Action taken: 0
# cart position: -1.8074764013290405
# cart velocity: -1.4420783519744873
# pole angle: -0.14232362806797028
# pole angular velocity: -0.007868936285376549
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 315:
# Action taken: 1
# cart position: -1.836318016052246
# cart velocity: -1.2452325820922852
# pole angle: -0.1424810141324997
# pole angular velocity: -0.3418542742729187
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 316:
# Action taken: 0
# cart position: -1.8612226247787476
# cart velocity: -1.4380704164505005
# pole angle: -0.14931809902191162
# pole angular velocity: -0.09727653115987778
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 317:
# Action taken: 0
# cart position: -1.889984130859375
# cart velocity: -1.6307718753814697
# pole angle: -0.15126362442970276
# pole angular velocity: 0.1448228359222412
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 318:
# Action taken: 1
# cart position: -1.9225995540618896
# cart velocity: -1.4338438510894775
# pole angle: -0.14836716651916504
# pole angular velocity: -0.19149844348430634
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 319:
# Action taken: 0
# cart position: -1.951276421546936
# cart velocity: -1.6265661716461182
# pole angle: -0.15219713747501373
# pole angular velocity: 0.0509490892291069
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 320:
# Action taken: 1
# cart position: -1.9838076829910278
# cart velocity: -1.429626703262329
# pole angle: -0.15117815136909485
# pole angular velocity: -0.28561878204345703
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 321:
# Action taken: 0
# cart position: -2.0124001502990723
# cart velocity: -1.6223056316375732
# pole angle: -0.15689052641391754
# pole angular velocity: -0.044174082577228546
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 322:
# Action taken: 1
# cart position: -2.044846296310425
# cart velocity: -1.4253225326538086
# pole angle: -0.15777401626110077
# pole angular velocity: -0.38195645809173584
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 323:
# Action taken: 0
# cart position: -2.073352813720703
# cart velocity: -1.6178936958312988
# pole angle: -0.16541314125061035
# pole angular velocity: -0.1428809016942978
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 324:
# Action taken: 0
# cart position: -2.105710744857788
# cart velocity: -1.8103079795837402
# pole angle: -0.1682707518339157
# pole angular velocity: 0.09339096397161484
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 325:
# Action taken: 1
# cart position: -2.1419167518615723
# cart velocity: -1.613223910331726
# pole angle: -0.1664029359817505
# pole angular velocity: -0.24729803204536438
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 326:
# Action taken: 0
# cart position: -2.1741812229156494
# cart velocity: -1.8056268692016602
# pole angle: -0.17134889960289001
# pole angular velocity: -0.011377125047147274
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 327:
# Action taken: 1
# cart position: -2.210293769836426
# cart velocity: -1.608514666557312
# pole angle: -0.17157644033432007
# pole angular velocity: -0.3528459370136261
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 328:
# Action taken: 0
# cart position: -2.242464065551758
# cart velocity: -1.8008345365524292
# pole angle: -0.17863336205482483
# pole angular velocity: -0.11879833787679672
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 329:
# Action taken: 0
# cart position: -2.2784807682037354
# cart velocity: -1.9930073022842407
# pole angle: -0.18100932240486145
# pole angular velocity: 0.11263448745012283
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 330:
# Action taken: 1
# cart position: -2.318341016769409
# cart velocity: -1.7958155870437622
# pole angle: -0.17875663936138153
# pole angular velocity: -0.23124727606773376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 331:
# Action taken: 0
# cart position: -2.354257345199585
# cart velocity: -1.9879928827285767
# pole angle: -0.183381587266922
# pole angular velocity: 0.0001502865634392947
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 332:
# Action taken: 1
# cart position: -2.394017219543457
# cart velocity: -1.7907793521881104
# pole angle: -0.18337857723236084
# pole angular velocity: -0.3443223536014557
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 333:
# Action taken: 0
# cart position: -2.429832696914673
# cart velocity: -1.9828836917877197
# pole angle: -0.19026502966880798
# pole angular velocity: -0.11460902541875839
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 333.0

# %% [markdown]
# ## Report Document

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Seed: {SEED}\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- Training curve shows how total episode rewards increased during training.\n")
    f.write("- Evaluation curve shows the mean performance of the trained model at fixed intervals.\n")
    f.write("- A smooth upward trend in both curves indicates stable learning.\n")
    f.write("- The final rewards approaching 500 suggest the agent solved the CartPole task.\n\n")

# %% [markdown]
# ## Plotting (Evaluation Curve + Training Curve)

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("CartPole-v1")

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/cartpole/ppo-cartpole/run_2025-10-11_21-29-23/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/cartpole/ppo-cartpole/run_2025-10-11_21-29-23/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the PPO agent before and after training.
    - 'Before training' shows a freshly initialized PPO agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline PPO agent episodes...")
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    baseline_model = PPO("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained PPO agent episodes...")
    model = PPO.load(str(model_file))
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_cartpole_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline PPO agent episodes...
# Baseline Episode 1: reward = 62.0
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/ppo-cartpole/run_2025-10-11_21-29-23/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 2: reward = 92.0
# Baseline Episode 3: reward = 47.0
# Baseline Episode 4: reward = 76.0
# Baseline Episode 5: reward = 72.0
#
# Recording trained PPO agent episodes...
# Trained Episode 1: reward = 378.0
# Trained Episode 2: reward = 500.0
# Trained Episode 3: reward = 500.0
# Trained Episode 4: reward = 302.0
# Trained Episode 5: reward = 500.0
