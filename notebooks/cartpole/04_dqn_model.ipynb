# %% [markdown]
# # PPO CartPole

# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/cartpole/dqn-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "dqn_cartpole"
monitor_file = str(monitor_dir) #/ "monitor_log.csv"

# %% [markdown]
# ## Training Model

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = Monitor(env, monitor_file)

# %%
model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8906     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 84       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1890     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 187      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.524    |
# |    n_updates        | 21       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2535     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 327      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.409    |
# |    n_updates        | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2669     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 381      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.398    |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2778     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 429      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.378    |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2868     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 477      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.357    |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2987     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 541      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.313    |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3060     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 590      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.243    |
# |    n_updates        | 122      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3112     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 664      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.251    |
# |    n_updates        | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3106     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 706      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 151      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3149     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 757      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.181    |
# |    n_updates        | 164      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3174     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 799      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.182    |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3190     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 842      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 185      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3218     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 885      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.119    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3243     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 927      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 206      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.0823   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3261     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 966      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0873   |
# |    n_updates        | 216      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3277     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1003     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 225      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3300     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1046     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0945   |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3320     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0733   |
# |    n_updates        | 245      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3340     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1124     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.077    |
# |    n_updates        | 255      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3354     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.066    |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3373     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1198     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0515   |
# |    n_updates        | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3390     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1236     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0443   |
# |    n_updates        | 283      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3403     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1274     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3416     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1313     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0425   |
# |    n_updates        | 303      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3428     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1348     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0574   |
# |    n_updates        | 311      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3442     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1387     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3450     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1423     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 330      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3465     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1462     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3477     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1498     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3490     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1536     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 358      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3499     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1571     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 367      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3509     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1609     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 377      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3521     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1649     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3533     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1687     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 396      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3549     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1728     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3556     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1769     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 417      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3569     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1808     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.6      |
# |    ep_rew_mean      | 9.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3574     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1845     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 436      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.55     |
# |    ep_rew_mean      | 9.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3581     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1882     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 445      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.58     |
# |    ep_rew_mean      | 9.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3585     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1924     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00659  |
# |    n_updates        | 455      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.59     |
# |    ep_rew_mean      | 9.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3579     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1962     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00809  |
# |    n_updates        | 465      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.52     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3581     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1998     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0072   |
# |    n_updates        | 474      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.53     |
# |    ep_rew_mean      | 9.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3586     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2037     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00536  |
# |    n_updates        | 484      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.56     |
# |    ep_rew_mean      | 9.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3490     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2080     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 494      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.58     |
# |    ep_rew_mean      | 9.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3497     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2119     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00968  |
# |    n_updates        | 504      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.63     |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 
     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 3649     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9296     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000175 |
# |    n_updates        | 2298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 3650     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9340     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.61e-05 |
# |    n_updates        | 2309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 3652     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9385     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.91e-05 |
# |    n_updates        | 2321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 3654     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9429     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.5e-05  |
# |    n_updates        | 2332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 3656     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9467     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000123 |
# |    n_updates        | 2341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 3657     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9507     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000121 |
# |    n_updates        | 2351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 3659     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9546     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.38e-05 |
# |    n_updates        | 2361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 3661     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9598     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.89e-05 |
# |    n_updates        | 2374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 3664     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9654     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.56e-05 |
# |    n_updates        | 2388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 3666     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9707     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0051   |
# |    n_updates        | 2401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 3667     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9748     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.75e-05 |
# |    n_updates        | 2411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 3669     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9787     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.48e-05 |
# |    n_updates        | 2421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 3670     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.64e-05 |
# |    n_updates        | 2431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 3672     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9870     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.92e-05 |
# |    n_updates        | 2442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 3673     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9917     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000119 |
# |    n_updates        | 2454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 3675     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9959     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.45e-05 |
# |    n_updates        | 2464     |
# ----------------------------------

# %%
# Reset environment
SEED = 23
observation, info = env.reset(seed=SEED)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:10000
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.01939331  0.01414582 -0.03713558 -0.0386292 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.019676225259900093
# cart velocity: 0.20978008210659027
# pole angle: -0.0379081629216671
# pole angular velocity: -0.34279361367225647
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 1
# cart position: 0.023871826007962227
# cart velocity: 0.4054202735424042
# pole angle: -0.04476403445005417
# pole angular velocity: -0.6471853852272034
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.031980231404304504
# cart velocity: 0.6011363863945007
# pole angle: -0.05770774185657501
# pole angular velocity: -0.9536216855049133
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 1
# cart position: 0.0440029576420784
# cart velocity: 0.7969852685928345
# pole angle: -0.07678017765283585
# pole angular velocity: -1.2638626098632812
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.059942662715911865
# cart velocity: 0.9930000901222229
# pole angle: -0.10205742716789246
# pole angular velocity: -1.579569935798645
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 1
# cart position: 0.07980266958475113
# cart velocity: 1.1891785860061646
# pole angle: -0.1336488276720047
# pole angular velocity: -1.9022592306137085
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.10358623415231705
# cart velocity: 1.3854690790176392
# pole angle: -0.17169401049613953
# pole angular velocity: -2.2332451343536377
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.13129562139511108
# cart velocity: 1.1923425197601318
# pole angle: -0.21635891497135162
# pole angular velocity: -1.9980450868606567
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 8.0

# %% [markdown]
# ## Report Document

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Seed: {SEED}\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- Training curve shows how total episode rewards increased during training.\n")
    f.write("- Evaluation curve shows the mean performance of the trained model at fixed intervals.\n")
    f.write("- A smooth upward trend in both curves indicates stable learning.\n")
    f.write("- The final rewards approaching 500 suggest the agent solved the CartPole task.\n\n")

# %% [markdown]
# ## Plotting (Evaluation Curve + Training Curve)

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("CartPole-v1")

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (DQN on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/cartpole/dqn-cartpole/run_2025-10-13_15-25-33/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (DQN on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/cartpole/dqn-cartpole/run_2025-10-13_15-25-33/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the DQN agent before and after training.
    - 'Before training' shows a freshly initialized DQN agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline DQN agent episodes...")
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    baseline_model = DQN("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="dqn_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=False)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained DQN agent episodes...")
    model = DQN.load(str(model_file))
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="dqn_cartpole_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline DQN agent episodes...
# Baseline Episode 1: reward = 10.0
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/dqn-cartpole/run_2025-10-13_15-25-33/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 2: reward = 9.0
# Baseline Episode 3: reward = 10.0
# Baseline Episode 4: reward = 9.0
# Baseline Episode 5: reward = 9.0
#
# Recording trained DQN agent episodes...
# Trained Episode 1: reward = 9.0
# Trained Episode 2: reward = 9.0
# Trained Episode 3: reward = 10.0
# Trained Episode 4: reward = 9.0
# Trained Episode 5: reward = 9.0
