# %% [markdown]
# # DQN CartPole

# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/cartpole/dqn-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "dqn_cartpole"
monitor_file = str(monitor_dir)

# %% [markdown]
# ## Training Model

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = Monitor(env, monitor_file)

# %%
model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.8     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1746     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 107      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.586    |
# |    n_updates        | 1        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2424     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 191      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.504    |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2729     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 243      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.485    |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3208     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 347      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3400     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 425      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.387    |
# |    n_updates        | 81       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3632     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 514      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3928     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 654      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.279    |
# |    n_updates        | 138      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4090     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 757      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.227    |
# |    n_updates        | 164      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4174     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 820      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.195    |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4252     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 900      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 199      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4318     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 971      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.166    |
# |    n_updates        | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4384     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1074     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4455     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1168     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0744   |
# |    n_updates        | 266      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4509     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1256     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0776   |
# |    n_updates        | 288      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4538     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1331     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4640     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1580     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 369      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1703     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4673     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1794     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 423      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4675     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1882     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 445      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.3     |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4707     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2026     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00786  |
# |    n_updates        | 481      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4724     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2150     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00518  |
# |    n_updates        | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4746     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2301     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00461  |
# |    n_updates        | 550      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4774     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2431     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00662  |
# |    n_updates        | 582      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4781     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2520     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00177  |
# |    n_updates        | 604      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4788     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2590     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00162  |
# |    n_updates        | 622      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4803     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2688     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00202  |
# |    n_updates        | 646      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26       |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4813     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2788     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00197  |
# |    n_updates        | 671      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4794     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2888     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00337  |
# |    n_updates        | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4785     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2959     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00177  |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4791     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3040     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00574  |
# |    n_updates        | 734      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4785     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3125     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00458  |
# |    n_updates        | 756      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4785     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3193     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00194  |
# |    n_updates        | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4790     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3247     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00415  |
# |    n_updates        | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4627     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3375     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00258  |
# |    n_updates        | 818      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4635     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3465     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00237  |
# |    n_updates        | 841      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4635     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3513     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0024   |
# |    n_updates        | 853      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4638     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3578     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00684  |
# |    n_updates        | 869      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4649     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3681     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00417  |
# |    n_updates        | 895      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4653     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3749     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000832 |
# |    n_updates        | 912      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4658     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3806     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000798 |
# |    n_updates        | 926      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4661     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3860     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00196  |
# |    n_updates        | 939      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4663     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3940     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000731 |
# |    n_updates        | 959      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4665     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4007     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00155  |
# |    n_updates        | 976      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4664     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4069     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000695 |
# |    n_updates        | 992      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.608    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4129     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00238  |
# |    n_updates        | 1007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4653     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4173     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000937 |
# |    n_updates        | 1018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4653     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4227     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00113  |
# |    n_updates        | 1031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4303     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000477 |
# |    n_updates        | 1050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4656     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000486 |
# |    n_updates        | 1066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4427     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 1081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4654     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4504     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00083  |
# |    n_updates        | 1100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4653     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4557     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000912 |
# |    n_updates        | 1114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4654     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4617     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000466 |
# |    n_updates        | 1129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4657     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4696     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000788 |
# |    n_updates        | 1148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4651     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4746     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 1161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4650     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4792     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000482 |
# |    n_updates        | 1172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4649     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4864     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00084  |
# |    n_updates        | 1190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 4644     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4926     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000282 |
# |    n_updates        | 1206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 4642     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4996     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00236  |
# |    n_updates        | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.521    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 4637     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5046     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 1236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 4633     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5114     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000322 |
# |    n_updates        | 1253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 4635     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5168     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000654 |
# |    n_updates        | 1266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 4604     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5222     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000512 |
# |    n_updates        | 1280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 4582     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5304     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000304 |
# |    n_updates        | 1300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.49     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4569     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5370     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000241 |
# |    n_updates        | 1317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4554     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5423     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 1330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 4522     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5480     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 1344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.475    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 4505     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5529     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000223 |
# |    n_updates        | 1357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 4499     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5583     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000432 |
# |    n_updates        | 1370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 4491     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5626     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000286 |
# |    n_updates        | 1381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 4488     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5674     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000419 |
# |    n_updates        | 1393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 4482     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5739     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000604 |
# |    n_updates        | 1409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 4476     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5798     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000222 |
# |    n_updates        | 1424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 4471     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5838     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000335 |
# |    n_updates        | 1434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 4465     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5886     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000326 |
# |    n_updates        | 1446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.436    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 4461     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5939     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000216 |
# |    n_updates        | 1459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4454     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5985     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000569 |
# |    n_updates        | 1471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4451     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6043     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000167 |
# |    n_updates        | 1485     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4447     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000198 |
# |    n_updates        | 1495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4443     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6132     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000441 |
# |    n_updates        | 1507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4439     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6187     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000566 |
# |    n_updates        | 1521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4434     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6235     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00023  |
# |    n_updates        | 1533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4430     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6294     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000433 |
# |    n_updates        | 1548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4428     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6338     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000161 |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 4422     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6406     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000598 |
# |    n_updates        | 1576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 4408     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6462     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000299 |
# |    n_updates        | 1590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 4404     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6509     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000195 |
# |    n_updates        | 1602     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4401     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6563     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000165 |
# |    n_updates        | 1615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4400     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6620     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000278 |
# |    n_updates        | 1629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.367    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4394     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6664     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000146 |
# |    n_updates        | 1640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4385     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6723     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000106 |
# |    n_updates        | 1655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# ...
# |    time_elapsed     | 15       |
# |    total_timesteps  | 65658    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 16389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 271      |
# |    ep_rew_mean      | 271      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 4236     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 66716    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.055    |
# |    n_updates        | 16653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | 279      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 4243     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 67929    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 16957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | 287      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 4250     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 69122    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 17255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 291      |
# |    ep_rew_mean      | 291      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 4256     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 70275    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 17543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 293      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 4262     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 71454    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 17838    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 291      |
# |    ep_rew_mean      | 291      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 4269     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 72737    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 18159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 291      |
# |    ep_rew_mean      | 291      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 4274     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 73743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00566  |
# |    n_updates        | 18410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 4280     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 74950    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 18712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 4279     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 75811    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 18927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 4284     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 76980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 19219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | 295      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 4289     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 78132    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00138  |
# |    n_updates        | 19507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 293      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 4293     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 79083    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00669  |
# |    n_updates        | 19745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 4298     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 80304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00859  |
# |    n_updates        | 20050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | 287      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 4301     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 81177    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00846  |
# |    n_updates        | 20269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 282      |
# |    ep_rew_mean      | 282      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 4304     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 82157    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 20514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 281      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 4308     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 83339    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00279  |
# |    n_updates        | 20809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | 279      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 4311     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 84474    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 21093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 280      |
# |    ep_rew_mean      | 280      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 4315     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 85704    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00294  |
# |    n_updates        | 21400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 281      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 4319     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 86861    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0547   |
# |    n_updates        | 21690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 281      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 4322     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 87947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 21961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 281      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 4325     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 88872    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 22192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 281      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 4328     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 89968    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00261  |
# |    n_updates        | 22466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | 279      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 4330     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 91016    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 22728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 274      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 4333     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 92058    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00857  |
# |    n_updates        | 22989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 276      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 4336     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 93290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 23297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | 275      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 4339     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 94175    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.359    |
# |    n_updates        | 23518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | 275      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 4342     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 95385    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00195  |
# |    n_updates        | 23821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 274      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 4342     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 96521    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00997  |
# |    n_updates        | 24105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 274      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 4345     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 97693    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 24398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | 275      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 4348     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 98949    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00347  |
# |    n_updates        | 24712    |
# ----------------------------------

# %%
# Reset environment
SEED = 42
observation, info = env.reset(seed=SEED)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:100000
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 1
# cart position: 0.0310429148375988
# cart velocity: 0.3830638527870178
# pole angle: 0.03102613240480423
# pole angular velocity: -0.5424507260322571
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 0
# cart position: 0.03870419040322304
# cart velocity: 0.1875198930501938
# pole angle: 0.020177118480205536
# pole angular velocity: -0.24015574157238007
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 1
# cart position: 0.042454589158296585
# cart velocity: 0.38234788179397583
# pole angle: 0.015374003909528255
# pole angular velocity: -0.5264065861701965
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 0
# cart position: 0.05010154843330383
# cart velocity: 0.18701301515102386
# pole angle: 0.004845872055739164
# pole angular velocity: -0.228919118642807
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 1
# cart position: 0.05384180694818497
# cart velocity: 0.38206538558006287
# pole angle: 0.0002674896386452019
# pole angular velocity: -0.5200695395469666
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 0
# cart position: 0.06148311495780945
# cart velocity: 0.18693967163562775
# pole angle: -0.010133901610970497
# pole angular velocity: -0.22730235755443573
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.06522190570831299
# cart velocity: -0.00803600624203682
# pole angle: -0.014679948799312115
# pole angular velocity: 0.06216682493686676
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 0
# cart position: 0.06506118923425674
# cart velocity: -0.20294444262981415
# pole angle: -0.013436611741781235
# pole angular velocity: 0.3501822054386139
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.061002299189567566
# cart velocity: -0.3978727459907532
# pole angle: -0.006432967726141214
# pole angular velocity: 0.6385980248451233
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 0
# cart position: 0.053044844418764114
# cart velocity: -0.5929043889045715
# pole angle: 0.006338993087410927
# pole angular velocity: 0.9292482137680054
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 1
# cart position: 0.04118675738573074
# cart velocity: -0.3978686034679413
# pole angle: 0.024923957884311676
# pole angular velocity: 0.6385639905929565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.03322938457131386
# cart velocity: -0.20310288667678833
# pole angle: 0.03769523650407791
# pole angular velocity: 0.35383307933807373
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 1
# cart position: 0.029167326167225838
# cart velocity: -0.00853664055466652
# pole angle: 0.04477189853787422
# pole angular velocity: 0.07327080518007278
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.02899659425020218
# cart velocity: 0.18591581284999847
# pole angle: 0.046237315982580185
# pole angular velocity: -0.2049570381641388
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 1
# cart position: 0.03271491080522537
# cart velocity: 0.3803471028804779
# pole angle: 0.042138174176216125
# pole angular velocity: -0.4827033281326294
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.04032185301184654
# cart velocity: 0.5748497843742371
# pole angle: 0.032484106719493866
# pole angular velocity: -0.7618134021759033
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.05181884765625
# cart velocity: 0.3792957365512848
# pole angle: 0.017247838899493217
# pole angular velocity: -0.4590884745121002
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.05940476059913635
# cart velocity: 0.5741696953773499
# pole angle: 0.008066070266067982
# pole angular velocity: -0.7462853193283081
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.07088815420866013
# cart velocity: 0.37893739342689514
# pole angle: -0.0068596359342336655
# pole angular velocity: -0.4510749578475952
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 0
# cart position: 0.07846690714359283
# cart velocity: 0.18391311168670654
# pole angle: -0.015881136059761047
# pole angular velocity: -0.1605621576309204
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 1
# cart position: 0.08214516937732697
# cart velocity: 0.37925878167152405
# pole angle: -0.01909237913787365
# pole angular velocity: -0.45821258425712585
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 0
# cart position: 0.08973034471273422
# cart velocity: 0.18441185355186462
# pole angle: -0.028256630524992943
# pole angular velocity: -0.17160828411579132
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.09341857582330704
# cart velocity: -0.010294505394995213
# pole angle: -0.03168879449367523
# pole angular velocity: 0.1120283380150795
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 0
# cart position: 0.09321268647909164
# cart velocity: -0.20494838058948517
# pole angle: -0.02944822981953621
# pole angular velocity: 0.39454761147499084
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: 0.08911371976137161
# cart velocity: -0.39964038133621216
# pole angle: -0.02155727706849575
# pole angular velocity: 0.6778024435043335
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 0
# cart position: 0.08112091571092606
# cart velocity: -0.5944563150405884
# pole angle: -0.008001227863132954
# pole angular velocity: 0.9636210799217224
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 1
# cart position: 0.0692317858338356
# cart velocity: -0.3992277681827545
# pole angle: 0.01127119455486536
# pole angular velocity: 0.6684353351593018
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 1
# cart position: 0.06124723330140114
# cart velocity: -0.2042643427848816
# pole angle: 0.024639900773763657
# pole angular velocity: 0.37932243943214417
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 1
# cart position: 0.05716194584965706
# cart velocity: -0.009500812739133835
# pole angle: 0.03222635015845299
# pole angular velocity: 0.09450922161340714
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 1
# cart position: 0.05697192996740341
# cart velocity: 0.18514478206634521
# pole angle: 0.034116532653570175
# pole angular velocity: -0.18783466517925262
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 1
# cart position: 0.06067482382059097
# cart velocity: 0.3797624409198761
# pole angle: 0.030359841883182526
# pole angular velocity: -0.46956294775009155
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 1
# cart position: 0.06827007234096527
# cart velocity: 0.5744426250457764
# pole angle: 0.02096858248114586
# pole angular velocity: -0.7525243163108826
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 0
# cart position: 0.07975892722606659
# cart velocity: 0.3790379464626312
# pole angle: 0.005918096285313368
# pole angular velocity: -0.4533173441886902
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: 0.08733968436717987
# cart velocity: 0.1838328093290329
# pole angle: -0.003148250747472048
# pole angular velocity: -0.15877485275268555
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: 0.09101634472608566
# cart velocity: 0.3789996802806854
# pole angle: -0.006323747802525759
# pole angular velocity: -0.45244932174682617
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: 0.09859633445739746
# cart velocity: 0.1839677393436432
# pole angle: -0.01537273358553648
# pole angular velocity: -0.1617663949728012
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 0
# cart position: 0.10227569192647934
# cart velocity: -0.010930809192359447
# pole angle: -0.018608061596751213
# pole angular velocity: 0.12602746486663818
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 0
# cart position: 0.1020570769906044
# cart velocity: -0.20578131079673767
# pole angle: -0.01608751341700554
# pole angular velocity: 0.4127821624279022
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 0
# cart position: 0.09794145077466965
# cart velocity: -0.4006715714931488
# pole angle: -0.007831869646906853
# pole angular velocity: 0.7003501653671265
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 1
# cart position: 0.08992801606655121
# cart velocity: -0.2054419219493866
# pole angle: 0.006175133865326643
# pole angular velocity: 0.4052121639251709
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 1
# cart position: 0.08581917732954025
# cart velocity: -0.01040808204561472
# pole angle: 0.014279376715421677
# pole angular velocity: 0.11448245495557785
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 1
# cart position: 0.0856110155582428
# cart velocity: 0.1845063865184784
# pole angle: 0.016569025814533234
# pole angular velocity: -0.17366144061088562
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 1
# cart position: 0.08930114656686783
# cart velocity: 0.3793873190879822
# pole angle: 0.013095797039568424
# pole angular velocity: -0.4610716700553894
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 0
# cart position: 0.09688889235258102
# cart velocity: 0.1840827465057373
# pole angle: 0.003874364076182246
# pole angular velocity: -0.16428986191749573
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 1
# cart position: 0.10057054460048676
# cart velocity: 0.37914901971817017
# pole angle: 0.0005885667633265257
# pole angular velocity: -0.4557480216026306
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 0
# cart position: 0.10815352946519852
# cart velocity: 0.18401876091957092
# pole angle: -0.0085263941437006
# pole angular velocity: -0.16287963092327118
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 0
# cart position: 0.11183390021324158
# cart velocity: -0.010980099439620972
# pole angle: -0.01178398635238409
# pole angular velocity: 0.12710128724575043
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 0
# cart position: 0.11161430180072784
# cart velocity: -0.20593127608299255
# pole angle: -0.009241960011422634
# pole angular velocity: 0.41604334115982056
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 0
# cart position: 0.10749567300081253
# cart velocity: -0.4009210169315338
# pole angle: -0.000921093684155494
# pole angular velocity: 0.7057983875274658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 1
# cart position: 0.09947725385427475
# cart velocity: -0.20578633248806
# pole angle: 0.013194873929023743
# pole angular velocity: 0.41282564401626587
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 1
# cart position: 0.09536152333021164
# cart velocity: -0.01085387822240591
# pole angle: 0.02145138755440712
# pole angular velocity: 0.12433161586523056
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 1
# cart position: 0.09514445066452026
# cart velocity: 0.18395428359508514
# pole angle: 0.023938018828630447
# pole angular velocity: -0.16150717437267303
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 1
# cart position: 0.09882353246212006
# cart velocity: 0.37872549891471863
# pole angle: 0.0207078754901886
# pole angular velocity: -0.44654321670532227
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 0
# cart position: 0.10639804601669312
# cart velocity: 0.18331682682037354
# pole angle: 0.011777011677622795
# pole angular velocity: -0.14740532636642456
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 1
# cart position: 0.11006437987089157
# cart velocity: 0.37826815247535706
# pole angle: 0.008828905411064625
# pole angular velocity: -0.43634968996047974
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 0
# cart position: 0.11762974411249161
# cart velocity: 0.18302235007286072
# pole angle: 0.00010191115870838985
# pole angular velocity: -0.140896737575531
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 1
# cart position: 0.1212901920080185
# cart velocity: 0.3781428337097168
# pole angle: -0.002716023474931717
# pole angular velocity: -0.4335474967956543
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 0
# cart position: 0.12885305285453796
# cart velocity: 0.1830594539642334
# pole angle: -0.011386973783373833
# pole angular velocity: -0.14172200858592987
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 0
# cart position: 0.13251423835754395
# cart velocity: -0.011897586286067963
# pole angle: -0.014221413992345333
# pole angular velocity: 0.1473468840122223
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 0
# cart position: 0.1322762817144394
# cart velocity: -0.2068130224943161
# pole angle: -0.011274476535618305
# pole angular velocity: 0.4355095326900482
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 0
# cart position: 0.12814001739025116
# cart velocity: -0.4017735719680786
# pole angle: -0.002564285648986697
# pole angular velocity: 0.7246171236038208
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 1
# cart position: 0.12010455131530762
# cart velocity: -0.20661625266075134
# pole angle: 0.011928057298064232
# pole angular velocity: 0.43112820386886597
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 1
# cart position: 0.11597222834825516
# cart velocity: -0.011665217578411102
# pole angle: 0.020550621673464775
# pole angular velocity: 0.14222922921180725
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 1
# cart position: 0.11573892086744308
# cart velocity: 0.18315647542476654
# pole angle: 0.023395206779241562
# pole angular velocity: -0.14390014111995697
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 1
# cart position: 0.11940205097198486
# cart velocity: 0.3779357075691223
# pole angle: 0.020517202094197273
# pole angular velocity: -0.4291114807128906
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 0
# cart position: 0.12696076929569244
# cart velocity: 0.1825292855501175
# pole angle: 0.011934973299503326
# pole angular velocity: -0.13003191351890564
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 1
# cart position: 0.1306113600730896
# cart velocity: 0.3774782717227936
# pole angle: 0.00933433510363102
# pole angular velocity: -0.4189257323741913
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 0
# cart position: 0.13816091418266296
# cart velocity: 0.1822252869606018
# pole angle: 0.000955820782110095
# pole angular velocity: -0.12331478297710419
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 0
# cart position: 0.14180542528629303
# cart velocity: -0.01291034184396267
# pole angle: -0.00151047483086586
# pole angular velocity: 0.16966953873634338
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 1
# cart position: 0.14154721796512604
# cart velocity: 0.18223319947719574
# pole angle: 0.001882915967144072
# pole angular velocity: -0.12348951399326324
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 0
# cart position: 0.14519187808036804
# cart velocity: -0.012915680184960365
# pole angle: -0.0005868743173778057
# pole angular velocity: 0.16978685557842255
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 1
# cart position: 0.1449335664510727
# cart velocity: 0.1822146624326706
# pole angle: 0.002808862831443548
# pole angular velocity: -0.12308114767074585
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 0
# cart position: 0.14857785403728485
# cart velocity: -0.012947413139045238
# pole angle: 0.0003472398966550827
# pole angular velocity: 0.17048661410808563
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 1
# cart position: 0.14831891655921936
# cart velocity: 0.182169571518898
# pole angle: 0.003756972262635827
# pole angular velocity: -0.12208674103021622
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 0
# cart position: 0.1519623100757599
# cart velocity: -0.01300600916147232
# pole angle: 0.0013152373721823096
# pole angular velocity: 0.1717790961265564
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 1
# cart position: 0.1517021805047989
# cart velocity: 0.18209709227085114
# pole angle: 0.004750819411128759
# pole angular velocity: -0.12048862129449844
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 0
# cart position: 0.1553441286087036
# cart velocity: -0.013092601671814919
# pole angle: 0.002341046929359436
# pole angular velocity: 0.1736893504858017
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 1
# cart position: 0.15508227050304413
# cart velocity: 0.18199576437473297
# pole angle: 0.005814834032207727
# pole angular velocity: -0.11825413256883621
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: 0.1587221920490265
# cart velocity: -0.013209013268351555
# pole angle: 0.003449751529842615
# pole angular velocity: 0.1762576401233673
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: 0.15845800936222076
# cart velocity: 0.18186339735984802
# pole angle: 0.006974904332309961
# pole angular velocity: -0.11533500999212265
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 0
# cart position: 0.16209527850151062
# cart velocity: -0.013357794843614101
# pole angle: 0.004668204113841057
# pole angular velocity: 0.1795402616262436
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 1
# cart position: 0.16182811558246613
# cart velocity: 0.1816970407962799
# pole angle: 0.008259009569883347
# pole angular velocity: -0.11166635900735855
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 0
# cart position: 0.16546206176280975
# cart velocity: -0.013542273081839085
# pole angle: 0.006025682203471661
# pole angular velocity: 0.18361075222492218
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 1
# cart position: 0.16519121825695038
# cart velocity: 0.18149293959140778
# pole angle: 0.009697897359728813
# pole angular velocity: -0.10716522485017776
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 0
# cart position: 0.1688210815191269
# cart velocity: -0.013766628690063953
# pole angle: 0.007554592564702034
# pole angular velocity: 0.18856149911880493
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 1
# cart position: 0.16854573786258698
# cart velocity: 0.18124642968177795
# pole angle: 0.011325822211802006
# pole angular velocity: -0.10172871500253677
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 0
# cart position: 0.17217066884040833
# cart velocity: -0.014035988599061966
# pole angle: 0.009291248396039009
# pole angular velocity: 0.19450584053993225
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 1
# cart position: 0.17188994586467743
# cart velocity: 0.18095183372497559
# pole angle: 0.013181365095078945
# pole angular velocity: -0.09523167461156845
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: 0.1755089908838272
# cart velocity: 0.37588241696357727
# pole angle: 0.01127673126757145
# pole angular velocity: -0.38372692465782166
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: 0.18302664160728455
# cart velocity: 0.18060217797756195
# pole angle: 0.0036021932028234005
# pole angular velocity: -0.08750991523265839
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 0
# cart position: 0.18663868308067322
# cart velocity: -0.01457122154533863
# pole angle: 0.00185199489351362
# pole angular velocity: 0.2063073217868805
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 0
# cart position: 0.18634726107120514
# cart velocity: -0.20971961319446564
# pole angle: 0.005978141445666552
# pole angular velocity: 0.49957388639450073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 1
# cart position: 0.1821528673171997
# cart velocity: -0.01468244381248951
# pole angle: 0.015969619154930115
# pole angular velocity: 0.2087809294462204
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 1
# cart position: 0.18185921013355255
# cart velocity: 0.18020756542682648
# pole angle: 0.0201452374458313
# pole angular velocity: -0.07882192730903625
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 1
# cart position: 0.18546336889266968
# cart velocity: 0.37503501772880554
# pole angle: 0.018568798899650574
# pole angular velocity: -0.3650815188884735
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 0
# cart position: 0.19296406209468842
# cart velocity: 0.17965416610240936
# pole angle: 0.011267169378697872
# pole angular velocity: -0.06660185009241104
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 0
# cart position: 0.1965571492910385
# cart velocity: -0.01562749780714512
# pole angle: 0.00993513222783804
# pole angular velocity: 0.2296145260334015
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 1
# cart position: 0.19624459743499756
# cart velocity: 0.1793510764837265
# pole angle: 0.01452742237597704
# pole angular velocity: -0.05991802364587784
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 1
# cart position: 0.19983161985874176
# cart velocity: 0.3742617666721344
# pole angle: 0.01332906261086464
# pole angular velocity: -0.3479822874069214
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 0
# cart position: 0.20731686055660248
# cart velocity: 0.17895278334617615
# pole angle: 0.006369416601955891
# pole angular velocity: -0.05112621188163757
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 0
# cart position: 0.21089591085910797
# cart velocity: -0.01625991426408291
# pole angle: 0.005346892401576042
# pole angular velocity: 0.24355949461460114
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 0
# cart position: 0.21057070791721344
# cart velocity: -0.21145783364772797
# pole angle: 0.010218081995844841
# pole angular velocity: 0.5379241704940796
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 1
# cart position: 0.20634154975414276
# cart velocity: -0.01648101396858692
# pole angle: 0.020976565778255463
# pole angular velocity: 0.2484782636165619
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 1
# cart position: 0.20601193606853485
# cart velocity: 0.17833518981933594
# pole angle: 0.025946130976080894
# pole angular velocity: -0.037515077739953995
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 1
# cart position: 0.20957863330841064
# cart velocity: 0.3730756342411041
# pole angle: 0.025195829570293427
# pole angular velocity: -0.3219001293182373
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 0
# cart position: 0.21704015135765076
# cart velocity: 0.17760412395000458
# pole angle: 0.01875782571732998
# pole angular velocity: -0.02137913554906845
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 1
# cart position: 0.22059223055839539
# cart velocity: 0.37245211005210876
# pole angle: 0.018330244347453117
# pole angular velocity: -0.30808523297309875
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 0
# cart position: 0.22804127633571625
# cart velocity: 0.17707383632659912
# pole angle: 0.012168538756668568
# pole angular velocity: -0.009678260423243046
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 1
# cart position: 0.23158276081085205
# cart velocity: 0.3720191717147827
# pole angle: 0.011974973604083061
# pole angular velocity: -0.29849717020988464
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 0
# cart position: 0.2390231341123581
# cart velocity: 0.17672859132289886
# pole angle: 0.00600503059104085
# pole angular velocity: -0.002061733277514577
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 0
# cart position: 0.24255770444869995
# cart velocity: -0.018478956073522568
# pole angle: 0.005963795818388462
# pole angular velocity: 0.2925097942352295
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 1
# cart position: 0.24218812584877014
# cart velocity: 0.17655745148658752
# pole angle: 0.011813991703093052
# pole angular velocity: 0.0017137154936790466
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 0
# cart position: 0.2457192838191986
# cart velocity: -0.018731912598013878
# pole angle: 0.01184826623648405
# pole angular velocity: 0.2981005609035492
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 1
# cart position: 0.2453446388244629
# cart velocity: 0.1762191504240036
# pole angle: 0.01781027764081955
# pole angular velocity: 0.009177790954709053
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 1
# cart position: 0.24886903166770935
# cart velocity: 0.3710812032222748
# pole angle: 0.017993833869695663
# pole angular velocity: -0.2778329849243164
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: 0.25629064440727234
# cart velocity: 0.17570725083351135
# pole angle: 0.012437173165380955
# pole angular velocity: 0.02047041989862919
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 0
# cart position: 0.25980478525161743
# cart velocity: -0.019590839743614197
# pole angle: 0.012846581637859344
# pole angular velocity: 0.31705132126808167
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 1
# cart position: 0.2594129741191864
# cart velocity: 0.1753457933664322
# pole angle: 0.01918760873377323
# pole angular velocity: 0.028447285294532776
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 1
# cart position: 0.26291990280151367
# cart velocity: 0.3701874017715454
# pole angle: 0.019756553694605827
# pole angular velocity: -0.25812050700187683
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 0
# cart position: 0.27032363414764404
# cart velocity: 0.17478905618190765
# pole angle: 0.014594143256545067
# pole angular velocity: 0.04072786122560501
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 1
# cart position: 0.2738194167613983
# cart velocity: 0.36969873309135437
# pole angle: 0.015408700332045555
# pole angular velocity: -0.24731497466564178
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 0
# cart position: 0.2812134027481079
# cart velocity: 0.17436014115810394
# pole angle: 0.010462401434779167
# pole angular velocity: 0.050188098102808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 0
# cart position: 0.2847006022930145
# cart velocity: -0.02091026119887829
# pole angle: 0.011466163210570812
# pole angular velocity: 0.3461535573005676
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 1
# cart position: 0.284282386302948
# cart velocity: 0.17404672503471375
# pole angle: 0.018389234319329262
# pole angular velocity: 0.05710827186703682
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 1
# cart position: 0.2877633273601532
# cart velocity: 0.36890023946762085
# pole angle: 0.01953139901161194
# pole angular velocity: -0.2297164648771286
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 0
# cart position: 0.295141339302063
# cart velocity: 0.17350471019744873
# pole angle: 0.014937070198357105
# pole angular velocity: 0.06906279921531677
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 0
# cart position: 0.29861143231391907
# cart velocity: -0.021828163415193558
# pole angle: 0.01631832681596279
# pole angular velocity: 0.36642077565193176
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 1
# cart position: 0.2981748580932617
# cart velocity: 0.1730581372976303
# pole angle: 0.02364674210548401
# pole angular velocity: 0.07892760634422302
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 1
# cart position: 0.3016360402107239
# cart velocity: 0.3678332567214966
# pole angle: 0.02522529475390911
# pole angular velocity: -0.20620191097259521
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 0
# cart position: 0.3089926838874817
# cart velocity: 0.17235983908176422
# pole angle: 0.02110125496983528
# pole angular velocity: 0.09433039277791977
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 1
# cart position: 0.312439888715744
# cart velocity: 0.36717310547828674
# pole angle: 0.022987863048911095
# pole angular velocity: -0.19162112474441528
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 0
# cart position: 0.31978335976600647
# cart velocity: 0.17172996699810028
# pole angle: 0.019155440852046013
# pole angular velocity: 0.10822395980358124
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 1
# cart position: 0.3232179582118988
# cart velocity: 0.3665722608566284
# pole angle: 0.02131992019712925
# pole angular velocity: -0.17835450172424316
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 0
# cart position: 0.3305493891239166
# cart velocity: 0.171151801943779
# pole angle: 0.01775282993912697
# pole angular velocity: 0.12097714841365814
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 1
# cart position: 0.33397242426872253
# cart velocity: 0.3660149574279785
# pole angle: 0.020172372460365295
# pole angular velocity: -0.16605247557163239
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 0
# cart position: 0.34129273891448975
# cart velocity: 0.17061014473438263
# pole angle: 0.01685132272541523
# pole angular velocity: 0.1329253762960434
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 0
# cart position: 0.34470492601394653
# cart velocity: -0.02474908158183098
# pole angle: 0.019509831443428993
# pole angular velocity: 0.4308766722679138
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 1
# cart position: 0.3442099392414093
# cart velocity: 0.17009124159812927
# pole angle: 0.028127364814281464
# pole angular velocity: 0.14440731704235077
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 1
# cart position: 0.34761178493499756
# cart velocity: 0.3647993206977844
# pole angle: 0.031015511602163315
# pole angular velocity: -0.13927091658115387
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: 0.354907751083374
# cart velocity: 0.16924719512462616
# pole angle: 0.02823009341955185
# pole angular velocity: 0.16303329169750214
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 1
# cart position: 0.35829269886016846
# cart velocity: 0.3639538884162903
# pole angle: 0.031490758061409
# pole angular velocity: -0.12061181664466858
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 0
# cart position: 0.3655717968940735
# cart velocity: 0.1683952510356903
# pole angle: 0.029078522697091103
# pole angular velocity: 0.18183746933937073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 1
# cart position: 0.36893969774246216
# cart velocity: 0.36308929324150085
# pole angle: 0.03271527215838432
# pole angular velocity: -0.10153227299451828
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 0
# cart position: 0.37620148062705994
# cart velocity: 0.1675141304731369
# pole angle: 0.03068462572991848
# pole angular velocity: 0.2012900710105896
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 1
# cart position: 0.3795517683029175
# cart velocity: 0.3621841073036194
# pole angle: 0.03471042588353157
# pole angular velocity: -0.08155756443738937
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 0
# cart position: 0.38679543137550354
# cart velocity: 0.16658221185207367
# pole angle: 0.033079277724027634
# pole angular velocity: 0.22187134623527527
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 1
# cart position: 0.3901270925998688
# cart velocity: 0.36121612787246704
# pole angle: 0.037516701966524124
# pole angular velocity: -0.060196250677108765
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 1
# cart position: 0.3973514139652252
# cart velocity: 0.5557806491851807
# pole angle: 0.0363127775490284
# pole angular velocity: -0.3408103287220001
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 0
# cart position: 0.40846702456474304
# cart velocity: 0.36016133427619934
# pole angle: 0.0294965710490942
# pole angular velocity: -0.03690122812986374
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 0
# cart position: 0.415670245885849
# cart velocity: 0.16462910175323486
# pole angle: 0.028758546337485313
# pole angular velocity: 0.2649402916431427
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 1
# cart position: 0.41896283626556396
# cart velocity: 0.3593290150165558
# pole angle: 0.03405735269188881
# pole angular velocity: -0.018534990027546883
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 0
# cart position: 0.4261493980884552
# cart velocity: 0.16373562812805176
# pole angle: 0.03368665277957916
# pole angular velocity: 0.28469589352607727
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 1
# cart position: 0.42942413687705994
# cart velocity: 0.3583613336086273
# pole angle: 0.039380572736263275
# pole angular velocity: 0.0028249691240489483
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 1
# cart position: 0.43659135699272156
# cart velocity: 0.552897036075592
# pole angle: 0.03943707048892975
# pole angular velocity: -0.27717745304107666
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 0
# cart position: 0.4476493000984192
# cart velocity: 0.35723528265953064
# pole angle: 0.03389352187514305
# pole angular velocity: 0.027678459882736206
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 1
# cart position: 0.4547939896583557
# cart velocity: 0.551855206489563
# pole angle: 0.034447092562913895
# pole angular velocity: -0.25412094593048096
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 0
# cart position: 0.46583110094070435
# cart velocity: 0.3562587797641754
# pole angle: 0.02936467155814171
# pole angular velocity: 0.049225084483623505
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 0
# cart position: 0.47295626997947693
# cart velocity: 0.1607283353805542
# pole angle: 0.03034917265176773
# pole angular velocity: 0.3510262668132782
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 1
# cart position: 0.4761708378791809
# cart velocity: 0.3554058372974396
# pole angle: 0.03736969828605652
# pole angular velocity: 0.06806578487157822
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 1
# cart position: 0.48327895998954773
# cart velocity: 0.549972653388977
# pole angle: 0.03873101621866226
# pole angular velocity: -0.21259653568267822
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 0
# cart position: 0.4942784011363983
# cart velocity: 0.3543189465999603
# pole angle: 0.034479085355997086
# pole angular velocity: 0.09204796701669693
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 163:
# Action taken: 1
# cart position: 0.5013647675514221
# cart velocity: 0.5489301681518555
# pole angle: 0.0363200418651104
# pole angular velocity: -0.18956053256988525
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 164:
# Action taken: 0
# cart position: 0.5123434066772461
# cart velocity: 0.35330796241760254
# pole angle: 0.0325288325548172
# pole angular velocity: 0.11435503512620926
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 165:
# Action taken: 1
# cart position: 0.5194095373153687
# cart velocity: 0.5479490756988525
# pole angle: 0.03481593355536461
# pole angular velocity: -0.16789039969444275
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 166:
# Action taken: 0
# cart position: 0.5303685069084167
# cart velocity: 0.3523465096950531
# pole angle: 0.03145812451839447
# pole angular velocity: 0.13556945323944092
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 167:
# Action taken: 1
# cart position: 0.5374154448509216
# cart velocity: 0.5470041036605835
# pole angle: 0.0341695137321949
# pole angular velocity: -0.14702527225017548
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 168:
# Action taken: 0
# cart position: 0.5483555197715759
# cart velocity: 0.3514098823070526
# pole angle: 0.031229007989168167
# pole angular velocity: 0.1562386304140091
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 169:
# Action taken: 1
# cart position: 0.5553837418556213
# cart velocity: 0.5460711121559143
# pole angle: 0.03435378149151802
# pole angular velocity: -0.12643100321292877
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 170:
# Action taken: 0
# cart position: 0.5663051605224609
# cart velocity: 0.3504742980003357
# pole angle: 0.03182516247034073
# pole angular velocity: 0.17688915133476257
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 171:
# Action taken: 1
# cart position: 0.5733146667480469
# cart velocity: 0.5451266765594482
# pole angle: 0.03536294400691986
# pole angular velocity: -0.10558656603097916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 172:
# Action taken: 0
# cart position: 0.5842171907424927
# cart velocity: 0.34951627254486084
# pole angle: 0.033251214772462845
# pole angular velocity: 0.19804014265537262
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 173:
# Action taken: 1
# cart position: 0.5912075042724609
# cart velocity: 0.544147253036499
# pole angle: 0.03721201419830322
# pole angular velocity: -0.08397086709737778
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 174:
# Action taken: 0
# cart position: 0.6020904779434204
# cart velocity: 0.3485121726989746
# pole angle: 0.035532597452402115
# pole angular velocity: 0.22021637856960297
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 175:
# Action taken: 1
# cart position: 0.6090607047080994
# cart velocity: 0.5431087017059326
# pole angle: 0.03993692621588707
# pole angular velocity: -0.06104973703622818
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 176:
# Action taken: 0
# cart position: 0.6199228763580322
# cart velocity: 0.3474375605583191
# pole angle: 0.03871593251824379
# pole angular velocity: 0.24396125972270966
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 177:
# Action taken: 1
# cart position: 0.626871645450592
# cart velocity: 0.5419857501983643
# pole angle: 0.04359515756368637
# pole angular velocity: -0.036262694746255875
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 178:
# Action taken: 0
# cart position: 0.6377113461494446
# cart velocity: 0.34626659750938416
# pole angle: 0.04286990314722061
# pole angular velocity: 0.269849956035614
# Reward: 1.0
# ...
# pole angle: 0.055834755301475525
# pole angular velocity: 0.15886040031909943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 203:
# Action taken: 1
# cart position: 0.9617074131965637
# cart velocity: 0.9092864394187927
# pole angle: 0.05901196599006653
# pole angular velocity: -0.11569851636886597
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 204:
# Action taken: 0
# cart position: 0.979893147945404
# cart velocity: 0.7133708000183105
# pole angle: 0.056697994470596313
# pole angular velocity: 0.19500289857387543
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 205:
# Action taken: 1
# cart position: 0.994160532951355
# cart velocity: 0.9076377749443054
# pole angle: 0.06059805303812027
# pole angular velocity: -0.07926909625530243
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 206:
# Action taken: 0
# cart position: 1.0123132467269897
# cart velocity: 0.7117018699645996
# pole angle: 0.05901267006993294
# pole angular velocity: 0.23190027475357056
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 207:
# Action taken: 1
# cart position: 1.0265473127365112
# cart velocity: 0.9059330821037292
# pole angle: 0.06365067511796951
# pole angular velocity: -0.041599780321121216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 208:
# Action taken: 0
# cart position: 1.044666051864624
# cart velocity: 0.7099589109420776
# pole angle: 0.06281867623329163
# pole angular velocity: 0.2704669237136841
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 209:
# Action taken: 1
# cart position: 1.0588651895523071
# cart velocity: 0.904130756855011
# pole angle: 0.06822802126407623
# pole angular velocity: -0.0017598883714526892
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 210:
# Action taken: 0
# cart position: 1.076947808265686
# cart velocity: 0.7081000208854675
# pole angle: 0.06819281727075577
# pole angular velocity: 0.3116455674171448
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 211:
# Action taken: 1
# cart position: 1.0911097526550293
# cart velocity: 0.9021875858306885
# pole angle: 0.07442573457956314
# pole angular velocity: 0.041224103420972824
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 212:
# Action taken: 0
# cart position: 1.1091535091400146
# cart velocity: 0.7060816287994385
# pole angle: 0.07525021582841873
# pole angular velocity: 0.3564296364784241
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 213:
# Action taken: 1
# cart position: 1.1232751607894897
# cart velocity: 0.9000575542449951
# pole angle: 0.0823788046836853
# pole angular velocity: 0.08839186280965805
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 214:
# Action taken: 1
# cart position: 1.1412763595581055
# cart velocity: 1.0939079523086548
# pole angle: 0.0841466411948204
# pole angular velocity: -0.17720572650432587
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 215:
# Action taken: 0
# cart position: 1.1631544828414917
# cart velocity: 0.8976889252662659
# pole angle: 0.08060252666473389
# pole angular velocity: 0.1407913714647293
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 216:
# Action taken: 1
# cart position: 1.1811082363128662
# cart velocity: 1.0915695428848267
# pole angle: 0.0834183543920517
# pole angular velocity: -0.12541382014751434
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 217:
# Action taken: 0
# cart position: 1.2029396295547485
# cart velocity: 0.8953577280044556
# pole angle: 0.0809100791811943
# pole angular velocity: 0.1923770010471344
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 218:
# Action taken: 1
# cart position: 1.2208467721939087
# cart velocity: 1.0892345905303955
# pole angle: 0.08475761860609055
# pole angular velocity: -0.07372532784938812
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 219:
# Action taken: 0
# cart position: 1.2426315546035767
# cart velocity: 0.8930062651634216
# pole angle: 0.08328311145305634
# pole angular velocity: 0.2444494664669037
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 220:
# Action taken: 1
# cart position: 1.2604916095733643
# cart velocity: 1.0868459939956665
# pole angle: 0.08817210048437119
# pole angular velocity: -0.020845457911491394
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 221:
# Action taken: 0
# cart position: 1.2822285890579224
# cart velocity: 0.890577495098114
# pole angle: 0.08775519579648972
# pole angular velocity: 0.29830271005630493
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 222:
# Action taken: 1
# cart position: 1.3000401258468628
# cart velocity: 1.084346055984497
# pole angle: 0.09372124820947647
# pole angular velocity: 0.03453521803021431
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 223:
# Action taken: 1
# cart position: 1.3217270374298096
# cart velocity: 1.2780077457427979
# pole angle: 0.0944119542837143
# pole angular velocity: -0.22716876864433289
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 224:
# Action taken: 0
# cart position: 1.3472871780395508
# cart velocity: 1.0816723108291626
# pole angle: 0.08986857533454895
# pole angular velocity: 0.09373882412910461
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 225:
# Action taken: 1
# cart position: 1.3689205646514893
# cart velocity: 1.2753989696502686
# pole angle: 0.0917433500289917
# pole angular velocity: -0.1692926436662674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 226:
# Action taken: 0
# cart position: 1.3944286108016968
# cart velocity: 1.0790917873382568
# pole angle: 0.08835750073194504
# pole angular velocity: 0.15086452662944794
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 227:
# Action taken: 1
# cart position: 1.4160103797912598
# cart velocity: 1.272844672203064
# pole angle: 0.09137479215860367
# pole angular velocity: -0.11268780380487442
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 228:
# Action taken: 0
# cart position: 1.44146728515625
# cart velocity: 1.076540231704712
# pole angle: 0.08912103623151779
# pole angular velocity: 0.2073671966791153
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 229:
# Action taken: 1
# cart position: 1.4629981517791748
# cart velocity: 1.27028226852417
# pole angle: 0.09326837956905365
# pole angular velocity: -0.05592557042837143
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 230:
# Action taken: 0
# cart position: 1.4884037971496582
# cart velocity: 1.0739552974700928
# pole angle: 0.09214986860752106
# pole angular velocity: 0.26466602087020874
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 231:
# Action taken: 1
# cart position: 1.509882926940918
# cart velocity: 1.267649531364441
# pole angle: 0.09744318574666977
# pole angular velocity: 0.0024112637620419264
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 232:
# Action taken: 0
# cart position: 1.53523588180542
# cart velocity: 1.0712748765945435
# pole angle: 0.09749141335487366
# pole angular velocity: 0.3241787850856781
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 233:
# Action taken: 1
# cart position: 1.5566613674163818
# cart velocity: 1.264883279800415
# pole angle: 0.10397499054670334
# pole angular velocity: 0.06376233696937561
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 234:
# Action taken: 1
# cart position: 1.5819590091705322
# cart velocity: 1.458372712135315
# pole angle: 0.10525023937225342
# pole angular velocity: -0.19439078867435455
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 235:
# Action taken: 0
# cart position: 1.6111265420913696
# cart velocity: 1.2619149684906006
# pole angle: 0.10136242210865021
# pole angular velocity: 0.12955158948898315
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 236:
# Action taken: 1
# cart position: 1.6363648176193237
# cart velocity: 1.4554498195648193
# pole angle: 0.10395345091819763
# pole angular velocity: -0.12951108813285828
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 237:
# Action taken: 0
# cart position: 1.6654738187789917
# cart velocity: 1.2590042352676392
# pole angle: 0.10136322677135468
# pole angular velocity: 0.19407391548156738
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 238:
# Action taken: 1
# cart position: 1.690653920173645
# cart velocity: 1.4525411128997803
# pole angle: 0.1052447110414505
# pole angular velocity: -0.06499157100915909
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 239:
# Action taken: 0
# cart position: 1.7197047472000122
# cart velocity: 1.2560800313949585
# pole angle: 0.10394487529993057
# pole angular velocity: 0.25895440578460693
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 240:
# Action taken: 1
# cart position: 1.744826316833496
# cart velocity: 1.4495762586593628
# pole angle: 0.10912396758794785
# pole angular velocity: 0.0007813001866452396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 241:
# Action taken: 0
# cart position: 1.773817777633667
# cart velocity: 1.2530722618103027
# pole angle: 0.1091395914554596
# pole angular velocity: 0.32580289244651794
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 242:
# Action taken: 1
# cart position: 1.7988792657852173
# cart velocity: 1.4464848041534424
# pole angle: 0.11565564572811127
# pole angular velocity: 0.06943365931510925
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 243:
# Action taken: 0
# cart position: 1.8278089761734009
# cart velocity: 1.2499110698699951
# pole angle: 0.11704432219266891
# pole angular velocity: 0.39625149965286255
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 244:
# Action taken: 1
# cart position: 1.8528071641921997
# cart velocity: 1.4431947469711304
# pole angle: 0.12496934831142426
# pole angular velocity: 0.14264211058616638
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 245:
# Action taken: 1
# cart position: 1.8816710710525513
# cart velocity: 1.6363259553909302
# pole angle: 0.12782219052314758
# pole angular velocity: -0.10815009474754333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 246:
# Action taken: 0
# cart position: 1.9143975973129272
# cart velocity: 1.4396260976791382
# pole angle: 0.12565919756889343
# pole angular velocity: 0.22197014093399048
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 247:
# Action taken: 1
# cart position: 1.943190097808838
# cart velocity: 1.6327488422393799
# pole angle: 0.1300985962152481
# pole angular velocity: -0.028583316132426262
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 248:
# Action taken: 0
# cart position: 1.9758450984954834
# cart velocity: 1.4360244274139404
# pole angle: 0.12952692806720734
# pole angular velocity: 0.3021507263183594
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 249:
# Action taken: 1
# cart position: 2.004565477371216
# cart velocity: 1.6290853023529053
# pole angle: 0.13556994497776031
# pole angular velocity: 0.05295981094241142
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 250:
# Action taken: 0
# cart position: 2.037147283554077
# cart velocity: 1.432306170463562
# pole angle: 0.1366291344165802
# pole angular velocity: 0.38515570759773254
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 251:
# Action taken: 1
# cart position: 2.065793514251709
# cart velocity: 1.6252508163452148
# pole angle: 0.14433225989341736
# pole angular velocity: 0.13848009705543518
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 252:
# Action taken: 1
# cart position: 2.0982985496520996
# cart velocity: 1.818042278289795
# pole angle: 0.14710184931755066
# pole angular velocity: -0.10541373491287231
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 253:
# Action taken: 0
# cart position: 2.1346592903137207
# cart velocity: 1.6211520433425903
# pole angle: 0.14499357342720032
# pole angular velocity: 0.22982411086559296
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 254:
# Action taken: 1
# cart position: 2.1670823097229004
# cart velocity: 1.8139365911483765
# pole angle: 0.14959006011486053
# pole angular velocity: -0.013839371502399445
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 255:
# Action taken: 0
# cart position: 2.2033610343933105
# cart velocity: 1.6170212030410767
# pole angle: 0.14931327104568481
# pole angular velocity: 0.32205069065093994
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 256:
# Action taken: 1
# cart position: 2.235701560974121
# cart velocity: 1.8097364902496338
# pole angle: 0.15575428307056427
# pole angular velocity: 0.07992932945489883
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 257:
# Action taken: 0
# cart position: 2.2718961238861084
# cart velocity: 1.6127644777297974
# pole angle: 0.15735287964344025
# pole angular velocity: 0.4174175262451172
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 258:
# Action taken: 1
# cart position: 2.3041515350341797
# cart velocity: 1.8053474426269531
# pole angle: 0.165701225399971
# pole angular velocity: 0.17818304896354675
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 259:
# Action taken: 0
# cart position: 2.3402583599090576
# cart velocity: 1.6082898378372192
# pole angle: 0.16926488280296326
# pole angular velocity: 0.5182144641876221
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 260:
# Action taken: 1
# cart position: 2.3724241256713867
# cart velocity: 1.8006750345230103
# pole angle: 0.17962917685508728
# pole angular velocity: 0.2832873463630676
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 261:
# Action taken: 1
# cart position: 2.408437728881836
# cart velocity: 1.9928410053253174
# pole angle: 0.18529492616653442
# pole angular velocity: 0.05220367759466171
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 261.0

# %% [markdown]
# ## Report Document

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Seed: {SEED}\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- Training curve shows how total episode rewards increased during training.\n")
    f.write("- Evaluation curve shows the mean performance of the trained model at fixed intervals.\n")
    f.write("- A smooth upward trend in both curves indicates stable learning.\n")
    f.write("- The final rewards approaching 500 suggest the agent solved the CartPole task.\n\n")

# %% [markdown]
# ## Plotting (Evaluation Curve + Training Curve)

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("CartPole-v1")

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (DQN on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/cartpole/dqn-cartpole/run_2025-10-15_11-16-42/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (DQN on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/cartpole/dqn-cartpole/run_2025-10-15_11-16-42/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the DQN agent before and after training.
    - 'Before training' shows a freshly initialized DQN agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline DQN agent episodes...")
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    baseline_model = DQN("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="dqn_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=False)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained DQN agent episodes...")
    model = DQN.load(str(model_file))
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="dqn_cartpole_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline DQN agent episodes...
# Baseline Episode 1: reward = 9.0
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/dqn-cartpole/run_2025-10-15_11-16-42/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 2: reward = 9.0
# Baseline Episode 3: reward = 9.0
# Baseline Episode 4: reward = 9.0
# Baseline Episode 5: reward = 10.0
#
# Recording trained DQN agent episodes...
# Trained Episode 1: reward = 260.0
# Trained Episode 2: reward = 211.0
# Trained Episode 3: reward = 258.0
# Trained Episode 4: reward = 251.0
# Trained Episode 5: reward = 341.0
