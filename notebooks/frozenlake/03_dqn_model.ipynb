# %%
from pathlib import Path
from datetime import datetime

import gymnasium as gym
from gymnasium.wrappers import RecordVideo

from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/frozenlake/dqn-frozenlake") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "dqn_frozenlake"
monitor_file = str(monitor_dir)

# %%
env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")
env = Monitor(env, monitor_file)

# %%
model = DQN(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=0.0005,
    gamma=0.99
) 
# verbose shows info printed while training
# learning rate how fast the neural network updates after each step ( small -> slow, large -> fast)
# gamma discount factor for rewards ( small-> focus on immediate rewards, large -> long term rewards)

model.learn(total_timesteps=100000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 19175    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 47       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8        |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 16904    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.42     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 17489    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 101      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3843     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 129      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00214  |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4258     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 199      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000459 |
# |    n_updates        | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.08     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4210     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 218      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000187 |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.79     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4278     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 246      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000197 |
# |    n_updates        | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9        |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4368     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 288      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000211 |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.75     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4397     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 315      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.95e-05 |
# |    n_updates        | 53       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4519     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 375      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000111 |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.93     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4503     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 393      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.89e-05 |
# |    n_updates        | 73       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.44     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4492     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 405      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.55e-05 |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.71     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4579     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 453      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.32e-05 |
# |    n_updates        | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.96     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4633     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 502      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.67e-05 |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.72     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4645     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 523      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.76e-05 |
# |    n_updates        | 105      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.64     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4637     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 553      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.17e-05 |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.49     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4634     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 577      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.83e-05 |
# |    n_updates        | 119      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.46     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4663     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 609      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.33e-05 |
# |    n_updates        | 127      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.47     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4669     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 644      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.79e-05 |
# |    n_updates        | 135      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.36     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4665     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 669      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.34e-05 |
# |    n_updates        | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.36     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4682     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 702      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.2e-06  |
# |    n_updates        | 150      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.27     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4691     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 728      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.27e-05 |
# |    n_updates        | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.11     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 746      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.91e-07 |
# |    n_updates        | 161      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.05     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4686     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 773      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.2e-06  |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.14     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4704     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 814      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.52e-05 |
# |    n_updates        | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.83     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4696     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 830      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.26e-06 |
# |    n_updates        | 182      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.91     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4703     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 855      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.85e-06 |
# |    n_updates        | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.69     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4677     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 870      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.8e-06  |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.81     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4693     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 910      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.83e-07 |
# |    n_updates        | 202      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.33     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4702     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 932      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.14e-06 |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.31     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4679     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 949      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.08e-05 |
# |    n_updates        | 212      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.4      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4701     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 986      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.56e-07 |
# |    n_updates        | 221      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.19     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4712     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1007     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.11e-06 |
# |    n_updates        | 226      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.04     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4699     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 
93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10472    |
# |    fps              | 3703     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99731    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.15e-06 |
# |    n_updates        | 24907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.6      |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10476    |
# |    fps              | 3703     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99755    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.08e-07 |
# |    n_updates        | 24913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.48     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10480    |
# |    fps              | 3703     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99780    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.84e-07 |
# |    n_updates        | 24919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.44     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10484    |
# |    fps              | 3699     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99806    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.67e-07 |
# |    n_updates        | 24926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.35     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10488    |
# |    fps              | 3699     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99827    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.29e-07 |
# |    n_updates        | 24931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.36     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10492    |
# |    fps              | 3699     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99853    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.49e-07 |
# |    n_updates        | 24938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.32     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10496    |
# |    fps              | 3699     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 99877    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.61e-07 |
# |    n_updates        | 24944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.17     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10500    |
# |    fps              | 3699     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 99901    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.79e-07 |
# |    n_updates        | 24950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.83     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10504    |
# |    fps              | 3699     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 99926    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.48e-07 |
# |    n_updates        | 24956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.71     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10508    |
# |    fps              | 3700     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 99952    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.25e-08 |
# |    n_updates        | 24962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.62     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10512    |
# |    fps              | 3699     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 99973    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.41e-07 |
# |    n_updates        | 24968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.59     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10516    |
# |    fps              | 3700     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 99996    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.95e-07 |
# |    n_updates        | 24973    |
# ----------------------------------

# %%
# Reset environment
SEED = 42
observation, info = env.reset(seed=SEED)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:100000
# Action space: Discrete(4)
# Observation space: Discrete(16)
# Starting observation: 0
# maxiumum number of steps per episode: 100

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["Left", "Down", "Right", "Up"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(int(action))

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}({labels[action]})")
    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 2(Right)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 2(Right)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 2(Right)
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 1.0

# %%
lake_layout = ["".join(row.decode("utf-8") for row in line) for line in env.unwrapped.desc]

obs_explanation = """\
**Observation (Discrete integer):**
- A single integer (0–15) representing the agent’s position on the 4×4 grid (16).
- Each cell in the grid corresponds to a unique state:
  - `S` — Start position (state 0)
  - `F` — Frozen tile (safe)
  - `H` — Hole (episode ends with no reward)
  - `G` — Goal (episode ends with +1 reward)

**Action Space (Discrete 4):**
- 0 → Left
- 1 → Down
- 2 → Right
- 3 → Up
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- The agent **falls into a hole (`H`)** → `terminated = True`
- The agent **reaches the goal (`G`)** → `terminated = True`
- The **maximum number of steps (100)** is reached → `truncated = True`

**Reward Structure:**
- `+1` for reaching the goal (`G`)
- `0` for all other tiles (including holes)
"""


with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Frozen Lake Layout\n")
    for line in lake_layout:
        f.write(line + "\n")
    f.write("\n")


    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Seed: {SEED}\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {env.observation_space}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- The training curve visualizes total episode rewards across timesteps.\n")
    f.write("- The evaluation curve measures average policy performance at fixed intervals.\n")
    f.write("- A positive slope suggests the DQN agent is learning an effective navigation strategy.\n\n")

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=5000, total_timesteps=100000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("FrozenLake-v1", is_slippery=False)

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (DQN on frozenlake)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/.venv/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/frozenlake/dqn-frozenlake/run_2025-11-05_10-55-28/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (DQN on FrozenLake)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/frozenlake/dqn-frozenlake/run_2025-11-05_10-55-28/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the DQN agent before and after training.
    - 'Before training' shows a freshly initialized DQN agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline DQN agent episodes...")
    env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")
    baseline_model = DQN("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="dqn_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=False)
            action = int(action)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained DQN agent episodes...")
    model = DQN.load(str(model_file))
    env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="dqn_frozenlake_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            action = int(action)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline DQN agent episodes...
# /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/.venv/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/documentation/frozenlake/dqn-frozenlake/run_2025-11-05_10-55-28/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 1: reward = 0.0
# Baseline Episode 2: reward = 0.0
# Baseline Episode 3: reward = 0.0
# Baseline Episode 4: reward = 0.0
# Baseline Episode 5: reward = 0.0
#
# Recording trained DQN agent episodes...
# Trained Episode 1: reward = 1.0
# Trained Episode 2: reward = 1.0
# Trained Episode 3: reward = 1.0
# Trained Episode 4: reward = 1.0
# Trained Episode 5: reward = 1.0
# /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/.venv/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/documentation/frozenlake/dqn-frozenlake/run_2025-11-05_10-55-28/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
