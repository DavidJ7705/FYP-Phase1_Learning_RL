# %%
from pathlib import Path
from datetime import datetime

import gymnasium as gym
from gymnasium.wrappers import RecordVideo

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/frozenlake/ppo-frozenlake") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_frozenlake"
monitor_file = str(monitor_dir)

# %%
env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")
env = Monitor(env, monitor_file)

# %%
model = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0005, gamma=0.99, n_steps=512)
model.learn(total_timesteps=100000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.71     |
# |    ep_rew_mean     | 0.0462   |
# | time/              |          |
# |    fps             | 6393     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 512      |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.42         |
# |    ep_rew_mean          | 0.05         |
# | time/                   |              |
# |    fps                  | 4022         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0061529772 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.525       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0251      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.018       |
# |    value_loss           | 0.0301       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.92        |
# |    ep_rew_mean          | 0.05        |
# | time/                   |             |
# |    fps                  | 3756        |
# |    iterations           | 3           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.013515538 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0327     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.031       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.45        |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 3639        |
# |    iterations           | 4           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.012459604 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0233     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 0.0316      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.72        |
# |    ep_rew_mean          | 0.17        |
# | time/                   |             |
# |    fps                  | 3552        |
# |    iterations           | 5           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.016383834 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00697    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 0.075       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.61        |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 3501        |
# |    iterations           | 6           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.019446146 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.034      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.0894      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.31        |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 3488        |
# |    iterations           | 7           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.023361962 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00841    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.36        |
# |    ep_rew_mean          | 0.78        |
# | time/                   |             |
# |    fps                  | 3471        |
# |    iterations           | 8           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017033253 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00388     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 0.0981      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.98        |
# |    ep_rew_mean          | 0.85        |
# | time/                   |             |
# |    fps                  | 3461        |
# |    iterations           | 9           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.017054994 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.0201      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0268     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 0.0565      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.65        |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 3465        |
# |    iterations           | 10          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011174252 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.0613      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00563    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 0.0518      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.4          |
# |    ep_rew_mean          | 0.95         |
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 11           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0098005645 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.00506      |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00103     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0203      |
# |    value_loss           | 0.0311       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.31        |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 3455        |
# |    iterations           | 12          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013033362 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.0552      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0292     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 0.0163      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.93        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 3440        |
# |    iterations           | 13          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.008685352 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.0614      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0033     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.12        |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 3434        |
# |    iterations           | 14          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.037784822 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0147     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0404     |
# |    value_loss           | 0.000202    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.46        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 3434        |
# |    iterations           | 15          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.011267543 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | 0.0571      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0294     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.0153      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.37        |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 3437        |
# |    iterations           | 16          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011331237 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.292      |
# |    explained_variance   | 0.0416      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.013      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.00631     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.29         |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 3438         |
# |    iterations           | 17           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0065810657 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.0331       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00373     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.0133       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.17        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 3435        |
# |    iterations           | 18          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.004745727 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | 0.0326      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0238     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00861     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.04         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3436         |
# |    iterations           | 19           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0013872688 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.127       |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00231     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 3.8e-05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.3          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3438         |
# |    iterations           | 20           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0047743246 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.128       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.165        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 2.17e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.05        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 3440        |
# |    iterations           | 21          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.081245005 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0819     |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0565     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 3.8e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.07         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3442         |
# |    iterations           | 22           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0017843882 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0436      |
# |    explained_variance   | 0.0617       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.000685    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 0.00632      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 3445        |
# |    iterations           | 23          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.000493343 |
# |    clip_fraction        | 0.00742     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0347     |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.018      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 2.22e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.02         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3447         |
# |    iterations           | 24           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0010387265 |
# |    clip_fraction        | 0.00332      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.024       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.000816    |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 2.41e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.01         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3449         |
# |    iterations           | 25           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0004959579 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0217      |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0175      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0058      |
# |    value_loss           | 6.7e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.02         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3450         |
# |    iterations           | 26           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 1.134933e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0195      |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00128     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000605    |
# |    value_loss           | 2.43e-09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3452         |
# |    iterations           | 27           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0007271457 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0164      |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 4.22e-05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 3.56e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3454          |
# |    iterations           | 28            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 2.2468157e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0145       |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000153     |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -6.61e-05     |
# |    value_loss           | 8.77e-09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.01          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3455          |
# |    iterations           | 29            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 1.1327211e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0155       |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000381     |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00013      |
# |    value_loss           | 1.2e-10       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.01          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3456          |
# |    iterations           | 30            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 0.00012719224 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0144       |
# |    explained_variance   | 0.997         |
# |    learning_rate        | 0.0005        |
# |    loss                 | 7.26e-05      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00241      |
# |    value_loss           | 9.11e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3458          |
# |    iterations           | 31            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 0.00063194335 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0131       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000704     |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00297      |
# |    value_loss           | 5e-07         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.04         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3460         |
# |    iterations           | 32           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0010249264 |
# |    clip_fraction        | 0.00332      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0214      |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00178     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 1.52e-09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3462         |
# |    iterations           | 33           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0034401095 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0211      |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.012       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00892     |
# |    value_loss           | 4.89e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.01          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3464          |
# |    iterations           | 34            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 1.8457649e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0166       |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000506     |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 1e-08         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3465         |
# |    iterations           | 35           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 0.0006695882 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0149      |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00137     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 9.01e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3467          |
# |    iterations           | 36            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00073377206 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.011        |
# |    explained_variance   | 0.999         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.019        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.004        |
# |    value_loss           | 9.71e-08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.01          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3469          |
# |    iterations           | 37            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 4.3888576e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00947      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000239     |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -7.18e-05     |
# |    value_loss           | 8.9e-11       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.02          |
# |    ep_rew_mean          | 0.99          |
# | time/                   |               |
# |    fps                  | 3470          |
# |    iterations           | 38            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00037149014 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00981      |
# |    explained_variance   | 0.999         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000159     |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00249      |
# |    value_loss           | 3.5e-07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3472         |
# |    iterations           | 39           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 0.0010114999 |
# |    clip_fraction        | 0.00449      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00807     |
# |    explained_variance   | 0.0614       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00965     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 0.00643      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.03          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3473          |
# |    iterations           | 40            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.0011718e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00735      |
# |    explained_variance   | 0.876         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000115     |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -4.88e-05     |
# |    value_loss           | 1.61e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3474         |
# |    iterations           | 41           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20992        |
# | train/                  |              |
# |    approx_kl            | 0.0034465732 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00636     |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0122      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00533     |
# |    value_loss           | 2.73e-06     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3475      |
# |    iterations           | 42        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 21504     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00627  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -1.51e-05 |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -8.08e-06 |
# |    value_loss           | 1.26e-08  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3476         |
# |    iterations           | 43           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 9.895302e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0065      |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0005       |
# |    loss                 | -3.99e-05    |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -2.25e-05    |
# |    value_loss           | 3.81e-11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3478          |
# |    iterations           | 44            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 4.1909516e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00715      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -5.57e-05     |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -2.84e-05     |
# |    value_loss           | 3.65e-14      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3478          |
# |    iterations           | 45            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 5.5879354e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00703      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -4.38e-05     |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -1.57e-05     |
# |    value_loss           | 1.77e-15      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3468      |
# |    iterations           | 46        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 23552     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00651  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -6.51e-05 |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -3.2e-05  |
# |    value_loss           | 6.2e-16   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3469      |
# |    iterations           | 47        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 24064     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0064   |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -5.93e-05 |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -2.66e-05 |
# |    value_loss           | 5.9e-16   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3470      |
# |    iterations           | 48        |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00653  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -5.84e-05 |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -2.52e-05 |
# |    value_loss           | 5.97e-16  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 49           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 3.981404e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00715     |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.000175    |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -7.11e-05    |
# |    value_loss           | 6.18e-16     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.01          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3472          |
# |    iterations           | 50            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 6.9173984e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00922      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000821     |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000253     |
# |    value_loss           | 5.9e-16       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.04          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3473          |
# |    iterations           | 51            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 1.2134085e-05 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0108       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000132     |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.00241      |
# |    value_loss           | 5.18e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3474         |
# |    iterations           | 52           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0017457763 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0109      |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.000155    |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 6.15e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3475         |
# |    iterations           | 53           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 27136        |
# | train/                  |              |
# |    approx_kl            | 3.958121e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00593     |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.000167    |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -8.97e-05    |
# |    value_loss           | 1.09e-07     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.01      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3476      |
# |    iterations           | 54        |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 27648     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00547  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -3.64e-05 |
# |    n_updates            | 530       |
# |    policy_gradient_loss | -1.4e-05  |
# |    value_loss           | 9.33e-10  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# ...
# |    n_updates            | 1770      |
# |    policy_gradient_loss | -3.03e-06 |
# |    value_loss           | 9.45e-12  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3468      |
# |    iterations           | 179       |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 91648     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00115  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -8.76e-06 |
# |    n_updates            | 1780      |
# |    policy_gradient_loss | -4.54e-06 |
# |    value_loss           | 1.33e-13  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3467      |
# |    iterations           | 180       |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00124  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -5.83e-06 |
# |    n_updates            | 1790      |
# |    policy_gradient_loss | -2.66e-06 |
# |    value_loss           | 2.57e-15  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3467      |
# |    iterations           | 181       |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 92672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00132  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -1.07e-05 |
# |    n_updates            | 1800      |
# |    policy_gradient_loss | -5.12e-06 |
# |    value_loss           | 4.11e-16  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3467      |
# |    iterations           | 182       |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 93184     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00141  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -2.48e-05 |
# |    n_updates            | 1810      |
# |    policy_gradient_loss | -8.96e-06 |
# |    value_loss           | 2.08e-17  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3467      |
# |    iterations           | 183       |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 93696     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00152  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0005    |
# |    loss                 | -5.39e-05 |
# |    n_updates            | 1820      |
# |    policy_gradient_loss | -2.06e-05 |
# |    value_loss           | 1.39e-16  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3467          |
# |    iterations           | 184           |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.0011718e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00179      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.000103     |
# |    n_updates            | 1830          |
# |    policy_gradient_loss | -4.19e-05     |
# |    value_loss           | 6.94e-18      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.03          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3467          |
# |    iterations           | 185           |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 94720         |
# | train/                  |               |
# |    approx_kl            | 5.2072573e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00292      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.00088      |
# |    n_updates            | 1840          |
# |    policy_gradient_loss | -0.000205     |
# |    value_loss           | 2.08e-17      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.01         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3467         |
# |    iterations           | 186          |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 0.0044025765 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00242     |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0306      |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00601     |
# |    value_loss           | 2.63e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3468          |
# |    iterations           | 187           |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 95744         |
# | train/                  |               |
# |    approx_kl            | 1.6298145e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00207      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -3.19e-05     |
# |    n_updates            | 1860          |
# |    policy_gradient_loss | -1.43e-05     |
# |    value_loss           | 1.16e-08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3468          |
# |    iterations           | 188           |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 3.8254075e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00391      |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.00191      |
# |    n_updates            | 1870          |
# |    policy_gradient_loss | -0.000438     |
# |    value_loss           | 1.82e-10      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.48       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 3468       |
# |    iterations           | 189        |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 96768      |
# | train/                  |            |
# |    approx_kl            | 0.24338421 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0586    |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0313    |
# |    n_updates            | 1880       |
# |    policy_gradient_loss | -0.0237    |
# |    value_loss           | 1e-12      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11         |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 3468       |
# |    iterations           | 190        |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 97280      |
# | train/                  |            |
# |    approx_kl            | 0.05686476 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.417     |
# |    explained_variance   | 0.0358     |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0255    |
# |    n_updates            | 1890       |
# |    policy_gradient_loss | -0.033     |
# |    value_loss           | 0.00231    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.94        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 3469        |
# |    iterations           | 191         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 97792       |
# | train/                  |             |
# |    approx_kl            | 0.016735297 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.283      |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.023      |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 0.000874    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.36        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 3469        |
# |    iterations           | 192         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011636427 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0446     |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 0.00031     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.36      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 3469      |
# |    iterations           | 193       |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 98816     |
# | train/                  |           |
# |    approx_kl            | 0.1332638 |
# |    clip_fraction        | 0.286     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.129    |
# |    explained_variance   | 0.708     |
# |    learning_rate        | 0.0005    |
# |    loss                 | -0.0525   |
# |    n_updates            | 1920      |
# |    policy_gradient_loss | -0.0479   |
# |    value_loss           | 0.000149  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 3469        |
# |    iterations           | 194         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.049418353 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0207     |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0273     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 2.05e-05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.04          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 3470          |
# |    iterations           | 195           |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 99840         |
# | train/                  |               |
# |    approx_kl            | 0.00010009401 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0142       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.00732      |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | -0.00167      |
# |    value_loss           | 5.16e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.05         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 3470         |
# |    iterations           | 196          |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0014738186 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0278      |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0229      |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 4.86e-06     |
# ------------------------------------------

# %%
# Reset environment
SEED = 42
observation, info = env.reset(seed=SEED)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:100352
# Action space: Discrete(4)
# Observation space: Discrete(16)
# Starting observation: 0
# maxiumum number of steps per episode: 100

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["Left", "Down", "Right", "Up"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(int(action))

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}({labels[action]})")
    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 2(Right)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 2(Right)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 2(Right)
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 1.0

# %%
lake_layout = ["".join(row.decode("utf-8") for row in line) for line in env.unwrapped.desc]

obs_explanation = """\
**Observation (Discrete integer):**
- A single integer (0–15) representing the agent’s position on the 4×4 grid (16).
- Each cell in the grid corresponds to a unique state:
  - `S` — Start position (state 0)
  - `F` — Frozen tile (safe)
  - `H` — Hole (episode ends with no reward)
  - `G` — Goal (episode ends with +1 reward)

**Action Space (Discrete 4):**
- 0 → Left
- 1 → Down
- 2 → Right
- 3 → Up
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- The agent **falls into a hole (`H`)** → `terminated = True`
- The agent **reaches the goal (`G`)** → `terminated = True`
- The **maximum number of steps (100)** is reached → `truncated = True`

**Reward Structure:**
- `+1` for reaching the goal (`G`)
- `0` for all other tiles (including holes)
"""


with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Frozen Lake Layout\n")
    for line in lake_layout:
        f.write(line + "\n")
    f.write("\n")


    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Seed: {SEED}\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {env.observation_space}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- The training curve visualizes total episode rewards across timesteps.\n")
    f.write("- The evaluation curve measures average policy performance at fixed intervals.\n")
    f.write("- A positive slope suggests the PPO agent is learning an effective navigation strategy.\n\n")

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=5000, total_timesteps=100000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("FrozenLake-v1", is_slippery=False)

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on frozenlake)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/.venv/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/frozenlake/ppo-frozenlake/run_2025-11-05_10-54-51/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (PPO on FrozenLake)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/frozenlake/ppo-frozenlake/run_2025-11-05_10-54-51/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the PPO agent before and after training.
    - 'Before training' shows a freshly initialized PPO agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline PPO agent episodes...")
    env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")
    baseline_model = PPO("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=False)
            action = int(action)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained PPO agent episodes...")
    model = PPO.load(str(model_file))
    env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_frozenlake_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            action = int(action)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline PPO agent episodes...
# /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/.venv/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/documentation/frozenlake/ppo-frozenlake/run_2025-11-05_10-54-51/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 1: reward = 0.0
# Baseline Episode 2: reward = 0.0
# Baseline Episode 3: reward = 0.0
# Baseline Episode 4: reward = 0.0
# Baseline Episode 5: reward = 0.0
#
# Recording trained PPO agent episodes...
# Trained Episode 1: reward = 1.0
# Trained Episode 2: reward = 1.0
# Trained Episode 3: reward = 1.0
# Trained Episode 4: reward = 1.0
# Trained Episode 5: reward = 1.0
# /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/.venv/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Desktop/FYP-Phase1_Learning_RL/documentation/frozenlake/ppo-frozenlake/run_2025-11-05_10-54-51/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
