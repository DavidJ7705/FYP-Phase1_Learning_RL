# %%
from pathlib import Path
from datetime import datetime

import gymnasium as gym
from gymnasium.wrappers import RecordVideo

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/frozenlake/ppo-frozenlake") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_frozenlake"
monitor_file = str(monitor_dir)

# %%
env = gym.make("FrozenLake-v1", is_slippery=True, render_mode="rgb_array")
env = Monitor(env, monitor_file)

# %%
model = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0005, gamma=0.99, n_steps=512)
model.learn(total_timesteps=100000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.16     |
# |    ep_rew_mean     | 0.0323   |
# | time/              |          |
# |    fps             | 5706     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 512      |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.76         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 3196         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0043326057 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -1.53        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0252      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00814     |
# |    value_loss           | 0.0231       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 3186         |
# |    iterations           | 3            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0036816732 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -12.4        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.022       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.86        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 3228        |
# |    iterations           | 4           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008100228 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00911    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.0186      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.13        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 3239        |
# |    iterations           | 5           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.010471572 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.033      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00841     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.88        |
# |    ep_rew_mean          | 0.03        |
# | time/                   |             |
# |    fps                  | 3255        |
# |    iterations           | 6           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008062962 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -37.7       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00812    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.06        |
# |    ep_rew_mean          | 0.03        |
# | time/                   |             |
# |    fps                  | 3261        |
# |    iterations           | 7           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.010971502 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0131     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00247     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.0368      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.4          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 3285         |
# |    iterations           | 8            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065455525 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -19.8        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.058       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0171      |
# |    value_loss           | 0.00115      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.75        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 3296        |
# |    iterations           | 9           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.011346528 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -5.02       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0476     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 2.2e-05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.04       |
# |    ep_rew_mean          | 0.05       |
# | time/                   |            |
# |    fps                  | 3303       |
# |    iterations           | 10         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.00985757 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.00927    |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0289     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.012     |
# |    value_loss           | 0.0169     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.76        |
# |    ep_rew_mean          | 0.04        |
# | time/                   |             |
# |    fps                  | 3312        |
# |    iterations           | 11          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.017980695 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00321    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 0.0368      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.5         |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 3313        |
# |    iterations           | 12          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013792271 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.103      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00619     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.0166      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 3311        |
# |    iterations           | 13          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.009817567 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.029      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | 0.04        |
# | time/                   |             |
# |    fps                  | 3307        |
# |    iterations           | 14          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009643715 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00492     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 0.0134      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | 0.07        |
# | time/                   |             |
# |    fps                  | 3308        |
# |    iterations           | 15          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.010026588 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0715      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00163     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.0362      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.8        |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 3311        |
# |    iterations           | 16          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008424291 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00433    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0345      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13          |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 3315        |
# |    iterations           | 17          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.008174445 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00423    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.0629      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | 0.1         |
# | time/                   |             |
# |    fps                  | 3319        |
# |    iterations           | 18          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008429527 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0048     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.0334      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 3293        |
# |    iterations           | 19          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.012592003 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00253    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 0.0456      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 3287        |
# |    iterations           | 20          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005097856 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0132      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 0.0371      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.3        |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 3285        |
# |    iterations           | 21          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.010981098 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00624    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.0583      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.9       |
# |    ep_rew_mean          | 0.18       |
# | time/                   |            |
# |    fps                  | 3275       |
# |    iterations           | 22         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.00667682 |
# |    clip_fraction        | 0.0697     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.618     |
# |    explained_variance   | -0.0215    |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0238     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 0.0618     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 3197        |
# |    iterations           | 23          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.010982839 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0143      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.056       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.3        |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 3197        |
# |    iterations           | 24          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008123995 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0452      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.0627      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18         |
# |    ep_rew_mean          | 0.15       |
# | time/                   |            |
# |    fps                  | 3196       |
# |    iterations           | 25         |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 12800      |
# | train/                  |            |
# |    approx_kl            | 0.00893563 |
# |    clip_fraction        | 0.0646     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.488     |
# |    explained_variance   | 0.0203     |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.00733    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 0.0452     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.3         |
# |    ep_rew_mean          | 0.19         |
# | time/                   |              |
# |    fps                  | 3192         |
# |    iterations           | 26           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0069095385 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | -0.00587     |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0133       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00574     |
# |    value_loss           | 0.0504       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.7         |
# |    ep_rew_mean          | 0.15         |
# | time/                   |              |
# |    fps                  | 3179         |
# |    iterations           | 27           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0042075943 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.373       |
# |    explained_variance   | 0.082        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0295       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00795     |
# |    value_loss           | 0.0646       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.7         |
# |    ep_rew_mean          | 0.21         |
# | time/                   |              |
# |    fps                  | 3176         |
# |    iterations           | 28           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0056434534 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.294       |
# |    explained_variance   | -0.11        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.000646     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00781     |
# |    value_loss           | 0.0282       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.8        |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 3182        |
# |    iterations           | 29          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.004175452 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.275      |
# |    explained_variance   | 0.0303      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.000732   |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.0663      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.9         |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 3188         |
# |    iterations           | 30           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0012137492 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.311       |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.045        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 0.0777       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | 0.32         |
# | time/                   |              |
# |    fps                  | 3193         |
# |    iterations           | 31           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 0.0074356454 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00463      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00946     |
# |    value_loss           | 0.0634       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 3200        |
# |    iterations           | 32          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003429833 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0311      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 0.0713      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.4         |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 3205         |
# |    iterations           | 33           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0042821444 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | 0.0206       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00102     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.0598       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23.8          |
# |    ep_rew_mean          | 0.34          |
# | time/                   |               |
# |    fps                  | 3210          |
# |    iterations           | 34            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 0.00090147124 |
# |    clip_fraction        | 0.0125        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.177        |
# |    explained_variance   | 0.0703        |
# |    learning_rate        | 0.0005        |
# |    loss                 | 0.0261        |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.00185      |
# |    value_loss           | 0.0525        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24          |
# |    ep_rew_mean          | 0.31        |
# | time/                   |             |
# |    fps                  | 3215        |
# |    iterations           | 35          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.002706202 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0395      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00661    |
# |    value_loss           | 0.0745      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.6         |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 3219         |
# |    iterations           | 36           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0018634768 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.162       |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0333       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00455     |
# |    value_loss           | 0.0398       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.3         |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 3223         |
# |    iterations           | 37           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 0.0031691054 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.182       |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00564      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 0.0605       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.6        |
# |    ep_rew_mean          | 0.24        |
# | time/                   |             |
# |    fps                  | 3227        |
# |    iterations           | 38          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.002610628 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | -0.0141     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00709     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00425    |
# |    value_loss           | 0.0438      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.8         |
# |    ep_rew_mean          | 0.22         |
# | time/                   |              |
# |    fps                  | 3231         |
# |    iterations           | 39           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 0.0038260538 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 0.0503       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00295     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 0.0503       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.3         |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 3229         |
# |    iterations           | 40           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0060679284 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.136       |
# |    explained_variance   | -0.0116      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0146       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00744     |
# |    value_loss           | 0.0552       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.7          |
# |    ep_rew_mean          | 0.31          |
# | time/                   |               |
# |    fps                  | 3225          |
# |    iterations           | 41            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 0.00042032264 |
# |    clip_fraction        | 0.00645       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.132        |
# |    explained_variance   | 0.0936        |
# |    learning_rate        | 0.0005        |
# |    loss                 | 0.0152        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.00102      |
# |    value_loss           | 0.06          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.5         |
# |    ep_rew_mean          | 0.37         |
# | time/                   |              |
# |    fps                  | 3227         |
# |    iterations           | 42           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0024162803 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.164       |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0287       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 0.0644       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 3222         |
# |    iterations           | 43           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 0.0017972816 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.147       |
# |    explained_variance   | 0.0998       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.043        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 0.0681       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.6         |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 3222         |
# |    iterations           | 44           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0031211278 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.173       |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0118       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00783     |
# |    value_loss           | 0.0499       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.5         |
# |    ep_rew_mean          | 0.48         |
# | time/                   |              |
# |    fps                  | 3224         |
# |    iterations           | 45           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 23040        |
# | train/                  |              |
# |    approx_kl            | 0.0011053013 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.111       |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.015        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 0.0369       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.5         |
# |    ep_rew_mean          | 0.49         |
# | time/                   |              |
# |    fps                  | 3227         |
# |    iterations           | 46           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0091246255 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | 0.00174      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00757      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 0.0495       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.6         |
# |    ep_rew_mean          | 0.52         |
# | time/                   |              |
# |    fps                  | 3230         |
# |    iterations           | 47           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 0.0029529848 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.147       |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00335      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00614     |
# |    value_loss           | 0.0392       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34           |
# |    ep_rew_mean          | 0.53         |
# | time/                   |              |
# |    fps                  | 3232         |
# |    iterations           | 48           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0016917102 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0328       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 0.0736       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.4         |
# |    ep_rew_mean          | 0.56         |
# | time/                   |              |
# |    fps                  | 3234         |
# |    iterations           | 49           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 0.0023375815 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.107       |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.03         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 0.061        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.2         |
# |    ep_rew_mean          | 0.56         |
# | time/                   |              |
# |    fps                  | 3237         |
# |    iterations           | 50           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0014766646 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0923      |
# |    explained_variance   | 0.0852       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0257       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 0.0614       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32           |
# |    ep_rew_mean          | 0.63         |
# | time/                   |              |
# |    fps                  | 3237         |
# |    iterations           | 51           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0028500815 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0998      |
# |    explained_variance   | -0.0507      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00812      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 0.0431       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.9         |
# |    ep_rew_mean          | 0.66         |
# | time/                   |              |
# |    fps                  | 3236         |
# |    iterations           | 52           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0026600414 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.016        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 0.0419       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.6       |
# |    ep_rew_mean          | 0.68       |
# | time/                   |            |
# |    fps                  | 3238       |
# |    iterations           | 53         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 27136      |
# | train/                  |            |
# |    approx_kl            | 0.00304934 |
# |    clip_fraction        | 0.0391     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.113     |
# |    explained_variance   | 0.131      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.00448    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00572   |
# |    value_loss           | 0.0381     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.4        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 3240        |
# |    iterations           | 54          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.001575816 |
# |    clip_fraction        | 0.00879     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.107      |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0177      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 0.0431      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.7        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 3241        |
# |    iterations           | 55          |
# |    time_elapsed         | 8           |
# ...
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 3472        |
# |    iterations           | 179         |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 91648       |
# | train/                  |             |
# |    approx_kl            | 0.003051973 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0354     |
# |    explained_variance   | -0.0174     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00331     |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 0.044       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.5        |
# |    ep_rew_mean          | 0.66        |
# | time/                   |             |
# |    fps                  | 3473        |
# |    iterations           | 180         |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.001623953 |
# |    clip_fraction        | 0.00664     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0484     |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0133      |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.000173   |
# |    value_loss           | 0.0436      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.2         |
# |    ep_rew_mean          | 0.69         |
# | time/                   |              |
# |    fps                  | 3473         |
# |    iterations           | 181          |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 92672        |
# | train/                  |              |
# |    approx_kl            | 0.0014403474 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0306      |
# |    explained_variance   | 0.00639      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.017        |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.0384       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.4        |
# |    ep_rew_mean          | 0.67        |
# | time/                   |             |
# |    fps                  | 3474        |
# |    iterations           | 182         |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.001029201 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0528     |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00807     |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.000945   |
# |    value_loss           | 0.0398      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.2         |
# |    ep_rew_mean          | 0.63         |
# | time/                   |              |
# |    fps                  | 3474         |
# |    iterations           | 183          |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 93696        |
# | train/                  |              |
# |    approx_kl            | 0.0021097597 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0339      |
# |    explained_variance   | 0.0206       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0209       |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 0.0395       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40           |
# |    ep_rew_mean          | 0.62         |
# | time/                   |              |
# |    fps                  | 3475         |
# |    iterations           | 184          |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0027523316 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0396      |
# |    explained_variance   | 0.0961       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0168       |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.006       |
# |    value_loss           | 0.0423       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.8         |
# |    ep_rew_mean          | 0.64         |
# | time/                   |              |
# |    fps                  | 3475         |
# |    iterations           | 185          |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 94720        |
# | train/                  |              |
# |    approx_kl            | 0.0005228602 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.042       |
# |    explained_variance   | 0.0603       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0143       |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00014     |
# |    value_loss           | 0.0473       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.6         |
# |    ep_rew_mean          | 0.64         |
# | time/                   |              |
# |    fps                  | 3476         |
# |    iterations           | 186          |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 0.0021969522 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.021       |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0192       |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00562     |
# |    value_loss           | 0.0464       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.7         |
# |    ep_rew_mean          | 0.65         |
# | time/                   |              |
# |    fps                  | 3476         |
# |    iterations           | 187          |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 95744        |
# | train/                  |              |
# |    approx_kl            | 7.713551e-05 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.023       |
# |    explained_variance   | 0.0893       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0171       |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -2.75e-05    |
# |    value_loss           | 0.0375       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | 0.67        |
# | time/                   |             |
# |    fps                  | 3477        |
# |    iterations           | 188         |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006619033 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0409     |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0155      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 0.0282      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.1         |
# |    ep_rew_mean          | 0.65         |
# | time/                   |              |
# |    fps                  | 3478         |
# |    iterations           | 189          |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 96768        |
# | train/                  |              |
# |    approx_kl            | 0.0003865296 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0477      |
# |    explained_variance   | 0.0844       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0143       |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.000985    |
# |    value_loss           | 0.0371       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.5        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 3478        |
# |    iterations           | 190         |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.001058221 |
# |    clip_fraction        | 0.00645     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0418     |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0234      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.000268   |
# |    value_loss           | 0.0354      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 42.8          |
# |    ep_rew_mean          | 0.68          |
# | time/                   |               |
# |    fps                  | 3478          |
# |    iterations           | 191           |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 97792         |
# | train/                  |               |
# |    approx_kl            | 0.00043618854 |
# |    clip_fraction        | 0.0141        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0415       |
# |    explained_variance   | 0.0905        |
# |    learning_rate        | 0.0005        |
# |    loss                 | 0.0272        |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -0.00267      |
# |    value_loss           | 0.0457        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.7         |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 3479         |
# |    iterations           | 192          |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0015861292 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0537      |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0105       |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 0.0196       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.1        |
# |    ep_rew_mean          | 0.72        |
# | time/                   |             |
# |    fps                  | 3479        |
# |    iterations           | 193         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 98816       |
# | train/                  |             |
# |    approx_kl            | 0.004072196 |
# |    clip_fraction        | 0.00859     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0438     |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00375     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 0.0232      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.8        |
# |    ep_rew_mean          | 0.73        |
# | time/                   |             |
# |    fps                  | 3480        |
# |    iterations           | 194         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.002803348 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0458     |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00876     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.4        |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 3480        |
# |    iterations           | 195         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 99840       |
# | train/                  |             |
# |    approx_kl            | 0.000873548 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0351     |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0255      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00159    |
# |    value_loss           | 0.0454      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 3481        |
# |    iterations           | 196         |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002406299 |
# |    clip_fraction        | 0.00293     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.031      |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00926     |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.000505   |
# |    value_loss           | 0.0278      |
# -----------------------------------------

# %%
# Reset environment
SEED = 42
observation, info = env.reset(seed=SEED)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:100352
# Action space: Discrete(4)
# Observation space: Discrete(16)
# Starting observation: 0
# maxiumum number of steps per episode: 100

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["Left", "Down", "Right", "Up"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(int(action))

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}({labels[action]})")
    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 0(Left)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0(Left)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 0(Left)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 3(Up)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1(Down)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0(Left)
# Reward: 0.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1(Down)
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 1.0

# %%
lake_layout = ["".join(row.decode("utf-8") for row in line) for line in env.unwrapped.desc]

obs_explanation = """\
**Observation (Discrete integer):**
- A single integer (0–15) representing the agent’s position on the 4×4 grid (16).
- Each cell in the grid corresponds to a unique state:
  - `S` — Start position (state 0)
  - `F` — Frozen tile (safe)
  - `H` — Hole (episode ends with no reward)
  - `G` — Goal (episode ends with +1 reward)

**Action Space (Discrete 4):**
- 0 → Left
- 1 → Down
- 2 → Right
- 3 → Up
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- The agent **falls into a hole (`H`)** → `terminated = True`
- The agent **reaches the goal (`G`)** → `terminated = True`
- The **maximum number of steps (100)** is reached → `truncated = True`

**Reward Structure:**
- `+1` for reaching the goal (`G`)
- `0` for all other tiles (including holes)
"""


with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Frozen Lake Layout\n")
    for line in lake_layout:
        f.write(line + "\n")
    f.write("\n")


    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Seed: {SEED}\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {env.observation_space}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- The training curve visualizes total episode rewards across timesteps.\n")
    f.write("- The evaluation curve measures average policy performance at fixed intervals.\n")
    f.write("- A positive slope suggests the PPO agent is learning an effective navigation strategy.\n\n")

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=5000, total_timesteps=100000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("FrozenLake-v1", is_slippery=True)

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on frozenlake)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/frozenlake/ppo-frozenlake/run_2025-10-25_13-16-51/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/frozenlake/ppo-frozenlake/run_2025-10-25_13-16-51/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the PPO agent before and after training.
    - 'Before training' shows a freshly initialized PPO agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline PPO agent episodes...")
    env = gym.make("FrozenLake-v1", is_slippery=True, render_mode="rgb_array")
    baseline_model = PPO("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=False)
            action = int(action)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained PPO agent episodes...")
    model = PPO.load(str(model_file))
    env = gym.make("FrozenLake-v1", is_slippery=True, render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_cartpole_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            action = int(action)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline PPO agent episodes...
# Baseline Episode 1: reward = 0.0
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/frozenlake/ppo-frozenlake/run_2025-10-25_13-16-51/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 2: reward = 0.0
# Baseline Episode 3: reward = 0.0
# Baseline Episode 4: reward = 0.0
# Baseline Episode 5: reward = 0.0
#
# Recording trained PPO agent episodes...
# Trained Episode 1: reward = 1.0
# Trained Episode 2: reward = 1.0
# Trained Episode 3: reward = 0.0
# Trained Episode 4: reward = 1.0
# Trained Episode 5: reward = 1.0
